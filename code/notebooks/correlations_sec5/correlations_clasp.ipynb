# %% [markdown]
# # Correlations: Information Value and Suprisal vs. Acceptability (Clasp)

# %%
### Import and utils
import ast
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import spearmanr
from collections import defaultdict, Counter
from scipy.stats import kendalltau, linregress
from tqdm.notebook import tqdm
from typing import List, Dict, Tuple, Optional, Union
from ast import literal_eval
import statsmodels.api as sm
import statsmodels.formula.api as smf


# For local imports
import sys
sys.path.append('../../')
from utils import load_jsonl, load_surprise_data


# Plots
sns.set_context("paper")
sns.set_style("whitegrid")
sns.set_palette("colorblind")
sns.set(font_scale=1.8)

# %% [markdown]
# ## Load data and preprocess

# %%
DATASETS = ['BLL2018']

DATASET_CONTEXT_MAP = {
    'switchboard': 'switchboard/switchboard_results_is.jsonl',
    'dailydialog': 'dailydialog/dailydialog_results_is.jsonl',
    'BLL2018': 'BLL2018/processed_ratings.jsonl',
    'brown': 'RTs/brown_rt.jsonl',
    'ns': 'RTs/ns_rt.jsonl',
    'provo': 'RTs/provo_rt.jsonl',
}

CORPUS_NAMES = {
    'switchboard': 'Switchboard',
    'dailydialog': 'Dailydialog',
    'BLL2018': 'Clasp',
    'provo': 'Provo',
    'brown': 'Brown',
    'ns': 'Natural Stories',
}

MODEL_NAME_MAP = {
    'gpt2': 'GPT-2 Small',
    'gpt2-ft': 'GPT-2 Small Finetuned', # todo: remove
    'gpt2_medium': 'GPT-2 Medium',
    'gpt2-medium': 'GPT-2 Medium',
    'gpt2_large': 'GPT-2 Large',
    'gpt2-large': 'GPT-2 Large',
    'dialogpt_small': 'DialoGPT Small',
    'dialogpt-small': 'DialoGPT Small',
    'dialogpt_medium': 'DialoGPT Medium',
    'dialogpt-medium': 'DialoGPT Medium',
    'dialogpt_large': 'DialoGPT Large',
    'dialogpt-large': 'DialoGPT Large',
    'opt_125m': 'OPT 125M',
    'opt-125m': 'OPT 125M',
    'opt_350m': 'OPT 350M',
    'opt-350m': 'OPT 350M',
    'opt_1.3b': 'OPT 1.3B',
    'opt-1.3b': 'OPT 1.3B',
    'gpt_neo_125m': 'GPT-Neo 125M',
    'gpt-neo-125m': 'GPT-Neo 125M',
    'gpt_neo_1.3b': 'GPT-Neo 1.3B',
    'gpt-neo-1.3b': 'GPT-Neo 1.3B',
    'gpt-neo-1.3B': 'GPT-Neo 1.3B',
}

SAMPLING_PARAM_MAP = {
    "None": "None", "02": "0.2", "03": "0.3", "075": "0.75", "08": "0.8",
    "085": "0.85", "09": "0.9", "095": "0.95", "125": "1.25"
}

SURPRISAL_COLUMNS = [
    'in_context_surprisal', #'out_of_context_surprisal', 'in_context_surprisal_rnd',
       # 'in_context_entropies', 'out_of_context_entropies', 'in_context_entropies_rnd',
       # 'in_context_deviations', 'out_of_context_deviations', 'in_context_deviations_rnd',
]

# %%
dfs = []
for dataset in DATASETS:
    print(f"Loading data for {dataset}...")
    DATA_DIR = f"../../../data/surprise/{dataset}"

    df = load_surprise_data(DATA_DIR)

    # Prettify column and value names
    df["corpus"] = df["corpus"].map(CORPUS_NAMES)
    df["sampling"] = df["sampling"].str.capitalize()
    df["sampling"] = df["sampling"].str.replace("Temp", "Temperature")

    df["model"] = df["model"].map(MODEL_NAME_MAP)

    sampling_param_map = {
        "None": "None", "02": "0.2", "03": "0.3", "075": "0.75", "08": "0.8",
        "085": "0.85", "09": "0.9", "095": "0.95", "125": "1.25"
    }
    df["sampling_param"] = df["sampling_param"].map(sampling_param_map)

    dfs.append(df)

surprise = pd.concat(dfs, axis=0, ignore_index=True)

# Merge sampling and sampling param column in surprise
surprise['sampling'] = surprise['sampling'].astype(str)
surprise['sampling_param'] = surprise['sampling_param'].astype(str)
surprise['sampling_strategy'] = surprise['sampling'] + '_' + surprise['sampling_param']
# Out:
# Loading data for BLL2018...
# Size of dataset: 440000 rows

# %%
POWER_RANGE = np.arange(0.5, 5.01, 0.25)

def local_diff(x):
    """from RUID"""
    d = 0
    for i in range(len(x)-1):
        d += abs(x[i+1]-x[i])
    return d

def power(x, y):
    """from RUID"""
#     if x.mask.all():
#         return np.nan
#     return np.nanmean(x**y)
    return np.nansum(x**y)

def load_surprisal_data(data_dir, columns, surprisal_columns):
    """
    Load data from a directory of CSV files containing surprisal estimates.
    # Arguments:
        data_dir (str): Path to directory containing CSV files.
        columns (list): columns to load from CSV files. If None, all columns are loaded.
        surprisal_columns (list): columns to format with ast (ugly but fine for now)
    """
    data = None
    for file in os.listdir(data_dir):
        if file.endswith(".csv"):
            dset = data_dir.split('/')
            fp = os.path.join(data_dir, file)
            df = pd.read_csv(fp, usecols=columns)

            # Store with fields
            fields_from_name = fp.split('/')
            df['corpus'] = CORPUS_NAMES[fields_from_name[-2]]
            df['model'] = MODEL_NAME_MAP[fields_from_name[-1][:-4]]

            # literal eval
            for column in surprisal_columns:
                df[column] = df[column].apply(
                    lambda s: [
                        ast.literal_eval(x.strip(' []'))
                        for x in s.split() if x.strip(' []')
                    ]
                )

            if "data" in locals():
                data = pd.concat([data, df])
            else:
                data = df

    print(f"Size of dataset: {data.shape} rows, cols")

    # Add sequence surprisal aggregates
    surprise_cols = [c for c in data.columns if ("in_" in c or "out_" in c) and "acceptability" not in c]
    # print(surprise_cols)
    for col in surprise_cols:
        try:
            data[f'{col}_agg_sum'] = data[col].apply(np.sum)
            data[f'{col}_agg_variance'] = data[col].apply(np.var)
            data[f'{col}_agg_max'] = data[col].apply(np.amax)
            data[f'{col}_agg_mean'] = data[col].apply(np.mean)
            data[f'{col}_agg_ldiff'] = data[col].apply(local_diff)
        except TypeError:
            print(f"TypeError for {col}")
            print(data[col].head())
        for p in POWER_RANGE:
            data[f'{col}_agg_power_' + str(p).replace('.', '_')] = data[col].apply(lambda x: power(x, p))

    print(f"Size of dataset: {data.shape} rows, cols")
    return data

# %%
# cols = ['context_id', 'random_context_id', 'time_sum_mean', 'time_sum_list',
       # 'time_count_nonzero', 'time_mean', 'time_sum_mean_NO',
       # 'time_sum_list_NO', 'time_count_nonzero_NO', 'time_mean_NO',]

all_surprisal_dfs = []
for dataset in DATASETS:
    print(f"Loading data for {dataset}...")
    DATA_DIR = f"../../../data/surprisal/{dataset}"

    all_cols = ['context_id', 'target_id', 'mean_acceptability_in_context']
    all_cols += SURPRISAL_COLUMNS

    surprisal_df = load_surprisal_data(DATA_DIR, all_cols, SURPRISAL_COLUMNS)
    all_surprisal_dfs.append(surprisal_df)

surprisal = pd.concat(all_surprisal_dfs, axis=0, ignore_index=True)

# surprisal['mutual_info'] = surprisal['in_context_surprisal_agg_mean'] - surprisal['out_of_context_surprisal_agg_mean']
# Out:
# Loading data for BLL2018...
# Size of dataset: (4000, 6) rows, cols
# Size of dataset: (4000, 30) rows, cols

# %%
len(surprise)/len(surprisal)
# Out:
# 110.0

# %% [markdown]
# ## Measure correlations

# %%
corrs = []
for corpus in tqdm(surprisal.corpus.unique()):
    for model in surprisal.model.unique():
        for measure in SURPRISAL_COLUMNS:
            for agg in ['agg_sum', 'agg_variance', 'agg_max', 'agg_mean', 'agg_ldiff'] + [f"agg_power_{str(p).replace('.', '_')}" for p in POWER_RANGE]:

                _df = surprisal[
                    (surprisal['model'] == model) &
                    (surprisal['corpus'] == corpus)
                ]
                assert(len(_df) == 100, f"Expected 100 rows, got {len(_df)}")

                if measure == 'mutual_info':
                    measure_name = measure
                else:
                    measure_name = f'{measure}_{agg}'

                rho, p = spearmanr(_df[measure_name], _df['mean_acceptability_in_context'], nan_policy="omit")

                corrs.append({
                    'corpus': corpus,
                    'model': model,
                    'n_samples': 'None',
                    'sampling': 'None',
                    'measure': measure,
                    'agg': agg,
                    'corr': rho,
                    'p-value': p,
                    'type': 'surprisal'
                })


iv_measures = [
    'surprise_mean_1gram', 'surprise_mean_2gram', 'surprise_mean_3gram',
    'surprise_mean_1gram_pos', 'surprise_mean_2gram_pos', 'surprise_mean_3gram_pos',
    'surprise_mean_cosine', 'surprise_mean_euclidean',
    'surprise_min_1gram', 'surprise_min_2gram', 'surprise_min_3gram',
    'surprise_min_1gram_pos', 'surprise_min_2gram_pos', 'surprise_min_3gram_pos',
    'surprise_min_cosine', 'surprise_min_euclidean'
]

for corpus in surprise.corpus.unique():
    for model in surprise.model.unique():
        print(model)
        for n_samples in tqdm(surprise.n_samples.unique()):
            for sampling in surprise.sampling_strategy.unique():
                for measure in iv_measures:
                    _df = surprise[
                        (surprise['model'] == model) &
                        (surprise['corpus'] == corpus) &
                        (surprise['n_samples'] == n_samples) &
                        (surprise['sampling_strategy'] == sampling)
                    ]
                    assert(len(_df) == 100, f"Expected 100 rows, got {len(_df)}")

                    rho, p = spearmanr(_df[measure], _df['mean_acceptability_in_context'], nan_policy="omit")

                    corrs.append({
                        'corpus': corpus,
                        'model': model,
                        'n_samples': n_samples,
                        'sampling': sampling,
                        'measure': measure,
                        'agg': 'None',
                        'corr': rho,
                        'p-value': p,
                        'type': 'iv'
                    })

corrs_df = pd.DataFrame(corrs)
# Out:
# <>:11: SyntaxWarning: assertion is always true, perhaps remove parentheses?
# <>:54: SyntaxWarning: assertion is always true, perhaps remove parentheses?
# <>:11: SyntaxWarning: assertion is always true, perhaps remove parentheses?
# <>:54: SyntaxWarning: assertion is always true, perhaps remove parentheses?
# /var/folders/0s/847v13g104z23kr193w_v2640000gn/T/ipykernel_61040/1083802112.py:11: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(len(_df) == 100, f"Expected 100 rows, got {len(_df)}")
#   0%|          | 0/1 [00:00<?, ?it/s]
# /var/folders/0s/847v13g104z23kr193w_v2640000gn/T/ipykernel_61040/1083802112.py:54: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(len(_df) == 100, f"Expected 100 rows, got {len(_df)}")
# GPT-Neo 1.3B
#   0%|          | 0/10 [00:00<?, ?it/s]
# GPT-2 Medium
#   0%|          | 0/10 [00:00<?, ?it/s]
# GPT-Neo 125M
#   0%|          | 0/10 [00:00<?, ?it/s]
# GPT-2 Large
#   0%|          | 0/10 [00:00<?, ?it/s]
# OPT 350M
#   0%|          | 0/10 [00:00<?, ?it/s]
# GPT-2 Small
#   0%|          | 0/10 [00:00<?, ?it/s]
# OPT 125M
#   0%|          | 0/10 [00:00<?, ?it/s]
# OPT 1.3B
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
corrs_df.to_csv("/Users/mario/code/surprise/code/notebooks/correlations/dataframes/correlations_clasp.csv", index=False)

# %% [markdown]
# ## Show rankings

# %%
corrs_df[
    (corrs_df.corpus == 'Clasp') &
    (corrs_df.type == 'surprisal')
].sort_values('corr', ascending=True).head(30)
# Out:
#     corpus         model n_samples sampling               measure
# 171  Clasp      OPT 125M      None     None  in_context_surprisal  \
# 27   Clasp      OPT 1.3B      None     None  in_context_surprisal
# 75   Clasp      OPT 350M      None     None  in_context_surprisal
# 123  Clasp   GPT-2 Large      None     None  in_context_surprisal
# 99   Clasp  GPT-Neo 1.3B      None     None  in_context_surprisal
# 3    Clasp  GPT-2 Medium      None     None  in_context_surprisal
# 51   Clasp   GPT-2 Small      None     None  in_context_surprisal
# 147  Clasp  GPT-Neo 125M      None     None  in_context_surprisal
# 40   Clasp      OPT 1.3B      None     None  in_context_surprisal
# 41   Clasp      OPT 1.3B      None     None  in_context_surprisal
# 39   Clasp      OPT 1.3B      None     None  in_context_surprisal
# 42   Clasp      OPT 1.3B      None     None  in_context_surprisal
# 38   Clasp      OPT 1.3B      None     None  in_context_surprisal
# 43   Clasp      OPT 1.3B      None     None  in_context_surprisal
# 44   Clasp      OPT 1.3B      None     None  in_context_surprisal
# 37   Clasp      OPT 1.3B      None     None  in_context_surprisal
# 112  Clasp  GPT-Neo 1.3B      None     None  in_context_surprisal
# 113  Clasp  GPT-Neo 1.3B      None     None  in_context_surprisal
# 114  Clasp  GPT-Neo 1.3B      None     None  in_context_surprisal
# 111  Clasp  GPT-Neo 1.3B      None     None  in_context_surprisal
# 45   Clasp      OPT 1.3B      None     None  in_context_surprisal
# 115  Clasp  GPT-Neo 1.3B      None     None  in_context_surprisal
# 110  Clasp  GPT-Neo 1.3B      None     None  in_context_surprisal
# 91   Clasp      OPT 350M      None     None  in_context_surprisal
# 90   Clasp      OPT 350M      None     None  in_context_surprisal
# 92   Clasp      OPT 350M      None     None  in_context_surprisal
# 116  Clasp  GPT-Neo 1.3B      None     None  in_context_surprisal
# 36   Clasp      OPT 1.3B      None     None  in_context_surprisal
# 93   Clasp      OPT 350M      None     None  in_context_surprisal
# 109  Clasp  GPT-Neo 1.3B      None     None  in_context_surprisal
#
#                 agg      corr       p-value       type
# 171        agg_mean -0.558615  2.268065e-42  surprisal
# 27         agg_mean -0.547677  1.777142e-40  surprisal
# 75         agg_mean -0.545489  4.170835e-40  surprisal
# 123        agg_mean -0.529620  1.690744e-37  surprisal
# 99         agg_mean -0.518461  9.566251e-36  surprisal
# 3          agg_mean -0.498946  7.842289e-33  surprisal
# 51         agg_mean -0.430965  4.967378e-24  surprisal
# 147        agg_mean -0.411792  6.923619e-22  surprisal
# 40   agg_power_3_25 -0.406959  2.287950e-21  surprisal
# 41    agg_power_3_5 -0.405595  3.194651e-21  surprisal
# 39    agg_power_3_0 -0.405364  3.380327e-21  surprisal
# 42   agg_power_3_75 -0.403372  5.486077e-21  surprisal
# 38   agg_power_2_75 -0.401143  9.396515e-21  surprisal
# 43    agg_power_4_0 -0.400833  1.012350e-20  surprisal
# 44   agg_power_4_25 -0.396050  3.165105e-20  surprisal
# 37    agg_power_2_5 -0.396033  3.177772e-20  surprisal
# 112  agg_power_3_25 -0.395862  3.309325e-20  surprisal
# 113   agg_power_3_5 -0.395031  4.025550e-20  surprisal
# 114  agg_power_3_75 -0.393759  5.428265e-20  surprisal
# 111   agg_power_3_0 -0.393106  6.325258e-20  surprisal
# 45    agg_power_4_5 -0.389789  1.368686e-19  surprisal
# 115   agg_power_4_0 -0.389758  1.378572e-19  surprisal
# 110  agg_power_2_75 -0.388716  1.753795e-19  surprisal
# 91    agg_power_4_0 -0.387889  2.121695e-19  surprisal
# 90   agg_power_3_75 -0.386741  2.761169e-19  surprisal
# 92   agg_power_4_25 -0.386303  3.051791e-19  surprisal
# 116  agg_power_4_25 -0.386122  3.180781e-19  surprisal
# 36   agg_power_2_25 -0.386108  3.191370e-19  surprisal
# 93    agg_power_4_5 -0.383035  6.415655e-19  surprisal
# 109   agg_power_2_5 -0.382969  6.512173e-19  surprisal

# %%
corrs_df[
    (corrs_df.corpus == 'Clasp') &
    (corrs_df.type == 'iv')
].sort_values('corr', ascending=True).head(30)
# Out:
#       corpus         model n_samples          sampling
# 7084   Clasp   GPT-2 Large       100      Nucleus_0.95  \
# 7020   Clasp   GPT-2 Large        90      Nucleus_0.85
# 1084   Clasp  GPT-Neo 1.3B        60  Temperature_1.25
# 14094  Clasp      OPT 1.3B        90  Temperature_0.75
# 14095  Clasp      OPT 1.3B        90  Temperature_0.75
# 14271  Clasp      OPT 1.3B       100  Temperature_0.75
# 14270  Clasp      OPT 1.3B       100  Temperature_0.75
# 1260   Clasp  GPT-Neo 1.3B        70  Temperature_1.25
# 13918  Clasp      OPT 1.3B        80  Temperature_0.75
# 13919  Clasp      OPT 1.3B        80  Temperature_0.75
# 11596  Clasp      OPT 125M        50      Nucleus_0.85
# 11420  Clasp      OPT 125M        40      Nucleus_0.85
# 14156  Clasp      OPT 1.3B       100       Nucleus_0.9
# 1436   Clasp  GPT-Neo 1.3B        80  Temperature_1.25
# 909    Clasp  GPT-Neo 1.3B        50  Temperature_1.25
# 6908   Clasp   GPT-2 Large        90      Nucleus_0.95
# 908    Clasp  GPT-Neo 1.3B        50  Temperature_1.25
# 6890   Clasp   GPT-2 Large        90  Temperature_1.25
# 13373  Clasp      OPT 1.3B        50    Ancestral_None
# 13980  Clasp      OPT 1.3B        90       Nucleus_0.9
# 14109  Clasp      OPT 1.3B       100  Temperature_1.25
# 13581  Clasp      OPT 1.3B        70  Temperature_1.25
# 7100   Clasp   GPT-2 Large       100       Nucleus_0.8
# 11244  Clasp      OPT 125M        30      Nucleus_0.85
# 13743  Clasp      OPT 1.3B        70  Temperature_0.75
# 13742  Clasp      OPT 1.3B        70  Temperature_0.75
# 6844   Clasp   GPT-2 Large        80      Nucleus_0.85
# 14076  Clasp      OPT 1.3B        90    Ancestral_None
# 11708  Clasp      OPT 125M        60      Typical_0.95
# 11418  Clasp      OPT 125M        40      Nucleus_0.85
#
#                       measure   agg      corr       p-value type
# 7084   surprise_min_2gram_pos  None -0.233694  1.251341e-07   iv
# 7020   surprise_min_2gram_pos  None -0.222530  4.991703e-07   iv
# 1084   surprise_min_2gram_pos  None -0.221416  5.708349e-07   iv
# 14094     surprise_min_cosine  None -0.221016  5.989753e-07   iv
# 14095  surprise_min_euclidean  None -0.221016  5.989753e-07   iv
# 14271  surprise_min_euclidean  None -0.218799  7.802537e-07   iv
# 14270     surprise_min_cosine  None -0.218799  7.802537e-07   iv
# 1260   surprise_min_2gram_pos  None -0.217021  9.627191e-07   iv
# 13918     surprise_min_cosine  None -0.216036  1.080875e-06   iv
# 13919  surprise_min_euclidean  None -0.216036  1.080875e-06   iv
# 11596  surprise_min_2gram_pos  None -0.215548  1.144311e-06   iv
# 11420  surprise_min_2gram_pos  None -0.215430  1.160251e-06   iv
# 14156  surprise_min_2gram_pos  None -0.215385  1.166310e-06   iv
# 1436   surprise_min_2gram_pos  None -0.214300  1.323438e-06   iv
# 909    surprise_min_3gram_pos  None -0.213865  1.392076e-06   iv
# 6908   surprise_min_2gram_pos  None -0.213347  1.478030e-06   iv
# 908    surprise_min_2gram_pos  None -0.213037  1.531892e-06   iv
# 6890       surprise_min_3gram  None -0.210000  2.221683e-06   iv
# 13373  surprise_min_3gram_pos  None -0.209839  2.262601e-06   iv
# 13980  surprise_min_2gram_pos  None -0.209806  2.218463e-06   iv
# 14109  surprise_min_3gram_pos  None -0.209647  2.312465e-06   iv
# 13581  surprise_min_3gram_pos  None -0.209145  2.447619e-06   iv
# 7100   surprise_min_2gram_pos  None -0.208786  2.490546e-06   iv
# 11244  surprise_min_2gram_pos  None -0.208318  2.625884e-06   iv
# 13743  surprise_min_euclidean  None -0.208115  2.686657e-06   iv
# 13742     surprise_min_cosine  None -0.208115  2.686657e-06   iv
# 6844   surprise_min_2gram_pos  None -0.207567  2.857701e-06   iv
# 14076  surprise_min_2gram_pos  None -0.206922  3.072387e-06   iv
# 11708  surprise_min_2gram_pos  None -0.206056  3.384878e-06   iv
# 11418      surprise_min_3gram  None -0.205824  3.552859e-06   iv

# %% [markdown]
# ## Find best estimator per corpus and linguistic level

# %%
# Out:
#             corpus           model n_samples          sampling
# 17822  Switchboard  DialoGPT Large       100  Temperature_1.25  \
# 17823  Switchboard  DialoGPT Large       100  Temperature_1.25
# 17647  Switchboard  DialoGPT Large        90  Temperature_1.25
# 17646  Switchboard  DialoGPT Large        90  Temperature_1.25
# 24703  Switchboard     GPT-2 Small        90      Typical_0.95
# 24702  Switchboard     GPT-2 Small        90      Typical_0.95
# 24878  Switchboard     GPT-2 Small       100      Typical_0.95
# 24879  Switchboard     GPT-2 Small       100      Typical_0.95
# 19742  Switchboard     GPT-2 Large       100    Ancestral_None
# 19743  Switchboard     GPT-2 Large       100    Ancestral_None
# 17470  Switchboard  DialoGPT Large        80  Temperature_1.25
# 17471  Switchboard  DialoGPT Large        80  Temperature_1.25
# 24862  Switchboard     GPT-2 Small       100  Temperature_1.25
# 24863  Switchboard     GPT-2 Small       100  Temperature_1.25
# 26735  Switchboard    GPT-Neo 1.3B       100      Typical_0.85
# 26734  Switchboard    GPT-Neo 1.3B       100      Typical_0.85
# 26558  Switchboard    GPT-Neo 1.3B        90      Typical_0.85
# 26559  Switchboard    GPT-Neo 1.3B        90      Typical_0.85
# 17815  Switchboard  DialoGPT Large       100  Temperature_1.25
# 26382  Switchboard    GPT-Neo 1.3B        80      Typical_0.85
#
#                        measure   agg      corr       p-value type
# 17822      surprise_min_cosine  None -0.702414  3.832227e-16   iv
# 17823   surprise_min_euclidean  None -0.702414  3.832227e-16   iv
# 17647   surprise_min_euclidean  None -0.692922  1.375102e-15   iv
# 17646      surprise_min_cosine  None -0.692922  1.375102e-15   iv
# 24703   surprise_min_euclidean  None -0.692855  1.387327e-15   iv
# 24702      surprise_min_cosine  None -0.692855  1.387327e-15   iv
# 24878      surprise_min_cosine  None -0.688118  2.576984e-15   iv
# 24879   surprise_min_euclidean  None -0.688118  2.576984e-15   iv
# 19742      surprise_min_cosine  None -0.681657  5.885868e-15   iv
# 19743   surprise_min_euclidean  None -0.681657  5.885868e-15   iv
# 17470      surprise_min_cosine  None -0.680088  7.170231e-15   iv
# 17471   surprise_min_euclidean  None -0.680088  7.170231e-15   iv
# 24862      surprise_min_cosine  None -0.679927  7.316152e-15   iv
# 24863   surprise_min_euclidean  None -0.679927  7.316152e-15   iv
# 26735   surprise_min_euclidean  None -0.678615  8.620250e-15   iv
# 26734      surprise_min_cosine  None -0.678615  8.620250e-15   iv
# 26558      surprise_min_cosine  None -0.675657  1.243817e-14   iv
# 26559   surprise_min_euclidean  None -0.675657  1.243817e-14   iv
# 17815  surprise_mean_euclidean  None -0.674861  1.371757e-14   iv
# 26382      surprise_min_cosine  None -0.674593  1.417731e-14   iv

# %%
corrs_df[
    (corrs_df.corpus == 'Clasp') &
    (corrs_df.type == "iv") &
    (~corrs_df.measure.str.contains('cosine')) &
    (~corrs_df.measure.str.contains('euclidean')) &
    (~corrs_df.measure.str.contains('pos'))
].sort_values('corr', ascending=True).head(20)
# Out:
#       corpus         model n_samples          sampling              measure
# 6890   Clasp   GPT-2 Large        90  Temperature_1.25   surprise_min_3gram  \
# 11418  Clasp      OPT 125M        40      Nucleus_0.85   surprise_min_3gram
# 7066   Clasp   GPT-2 Large       100  Temperature_1.25   surprise_min_3gram
# 6882   Clasp   GPT-2 Large        90  Temperature_1.25  surprise_mean_3gram
# 11594  Clasp      OPT 125M        50      Nucleus_0.85   surprise_min_3gram
# 11410  Clasp      OPT 125M        40      Nucleus_0.85  surprise_mean_3gram
# 11242  Clasp      OPT 125M        30      Nucleus_0.85   surprise_min_3gram
# 7058   Clasp   GPT-2 Large       100  Temperature_1.25  surprise_mean_3gram
# 12122  Clasp      OPT 125M        80      Nucleus_0.85   surprise_min_3gram
# 11586  Clasp      OPT 125M        50      Nucleus_0.85  surprise_mean_3gram
# 1114   Clasp  GPT-Neo 1.3B        60       Nucleus_0.8   surprise_min_3gram
# 1290   Clasp  GPT-Neo 1.3B        70       Nucleus_0.8   surprise_min_3gram
# 12114  Clasp      OPT 125M        80      Nucleus_0.85  surprise_mean_3gram
# 1466   Clasp  GPT-Neo 1.3B        80       Nucleus_0.8   surprise_min_3gram
# 13434  Clasp      OPT 1.3B        60       Nucleus_0.8   surprise_min_3gram
# 6538   Clasp   GPT-2 Large        70  Temperature_1.25   surprise_min_3gram
# 650    Clasp  GPT-Neo 1.3B        30       Typical_0.2   surprise_min_3gram
# 1642   Clasp  GPT-Neo 1.3B        90       Nucleus_0.8   surprise_min_3gram
# 13242  Clasp      OPT 1.3B        50      Nucleus_0.95   surprise_min_3gram
# 11234  Clasp      OPT 125M        30      Nucleus_0.85  surprise_mean_3gram
#
#         agg      corr   p-value type
# 6890   None -0.210000  0.000002   iv
# 11418  None -0.205824  0.000004   iv
# 7066   None -0.204071  0.000004   iv
# 6882   None -0.202738  0.000005   iv
# 11594  None -0.200002  0.000007   iv
# 11410  None -0.199666  0.000007   iv
# 11242  None -0.195138  0.000011   iv
# 7058   None -0.194668  0.000012   iv
# 12122  None -0.194549  0.000012   iv
# 11586  None -0.194251  0.000012   iv
# 1114   None -0.193724  0.000013   iv
# 1290   None -0.192898  0.000014   iv
# 12114  None -0.191886  0.000016   iv
# 1466   None -0.188024  0.000023   iv
# 13434  None -0.187417  0.000025   iv
# 6538   None -0.185286  0.000031   iv
# 650    None -0.184317  0.000034   iv
# 1642   None -0.183320  0.000037   iv
# 13242  None -0.182848  0.000040   iv
# 11234  None -0.181744  0.000044   iv

# %%
corrs_df[
    (corrs_df.corpus == 'Clasp') &
    (corrs_df.type == "iv") &
    (corrs_df.measure.str.contains('pos'))
].sort_values('corr', ascending=True).head(10)
# Out:
#       corpus         model n_samples          sampling
# 7084   Clasp   GPT-2 Large       100      Nucleus_0.95  \
# 7020   Clasp   GPT-2 Large        90      Nucleus_0.85
# 1084   Clasp  GPT-Neo 1.3B        60  Temperature_1.25
# 1260   Clasp  GPT-Neo 1.3B        70  Temperature_1.25
# 11596  Clasp      OPT 125M        50      Nucleus_0.85
# 11420  Clasp      OPT 125M        40      Nucleus_0.85
# 14156  Clasp      OPT 1.3B       100       Nucleus_0.9
# 1436   Clasp  GPT-Neo 1.3B        80  Temperature_1.25
# 909    Clasp  GPT-Neo 1.3B        50  Temperature_1.25
# 6908   Clasp   GPT-2 Large        90      Nucleus_0.95
#
#                       measure   agg      corr       p-value type
# 7084   surprise_min_2gram_pos  None -0.233694  1.251341e-07   iv
# 7020   surprise_min_2gram_pos  None -0.222530  4.991703e-07   iv
# 1084   surprise_min_2gram_pos  None -0.221416  5.708349e-07   iv
# 1260   surprise_min_2gram_pos  None -0.217021  9.627191e-07   iv
# 11596  surprise_min_2gram_pos  None -0.215548  1.144311e-06   iv
# 11420  surprise_min_2gram_pos  None -0.215430  1.160251e-06   iv
# 14156  surprise_min_2gram_pos  None -0.215385  1.166310e-06   iv
# 1436   surprise_min_2gram_pos  None -0.214300  1.323438e-06   iv
# 909    surprise_min_3gram_pos  None -0.213865  1.392076e-06   iv
# 6908   surprise_min_2gram_pos  None -0.213347  1.478030e-06   iv

# %%
corrs_df[
    (corrs_df.corpus == 'Clasp') &
    (corrs_df.type == "iv") &
    (corrs_df.measure.str.contains('cosine') | corrs_df.measure.str.contains('euclidean'))
].sort_values('corr', ascending=True).head(20)
# Out:
#       corpus     model n_samples          sampling                 measure
# 14094  Clasp  OPT 1.3B        90  Temperature_0.75     surprise_min_cosine  \
# 14095  Clasp  OPT 1.3B        90  Temperature_0.75  surprise_min_euclidean
# 14271  Clasp  OPT 1.3B       100  Temperature_0.75  surprise_min_euclidean
# 14270  Clasp  OPT 1.3B       100  Temperature_0.75     surprise_min_cosine
# 13918  Clasp  OPT 1.3B        80  Temperature_0.75     surprise_min_cosine
# 13919  Clasp  OPT 1.3B        80  Temperature_0.75  surprise_min_euclidean
# 13742  Clasp  OPT 1.3B        70  Temperature_0.75     surprise_min_cosine
# 13743  Clasp  OPT 1.3B        70  Temperature_0.75  surprise_min_euclidean
# 14238  Clasp  OPT 1.3B       100      Nucleus_0.85     surprise_min_cosine
# 14239  Clasp  OPT 1.3B       100      Nucleus_0.85  surprise_min_euclidean
# 13774  Clasp  OPT 1.3B        80      Nucleus_0.95     surprise_min_cosine
# 13775  Clasp  OPT 1.3B        80      Nucleus_0.95  surprise_min_euclidean
# 13567  Clasp  OPT 1.3B        60  Temperature_0.75  surprise_min_euclidean
# 13566  Clasp  OPT 1.3B        60  Temperature_0.75     surprise_min_cosine
# 13391  Clasp  OPT 1.3B        50  Temperature_0.75  surprise_min_euclidean
# 13390  Clasp  OPT 1.3B        50  Temperature_0.75     surprise_min_cosine
# 13951  Clasp  OPT 1.3B        90      Nucleus_0.95  surprise_min_euclidean
# 13950  Clasp  OPT 1.3B        90      Nucleus_0.95     surprise_min_cosine
# 12862  Clasp  OPT 1.3B        20  Temperature_0.75     surprise_min_cosine
# 12863  Clasp  OPT 1.3B        20  Temperature_0.75  surprise_min_euclidean
#
#         agg      corr       p-value type
# 14094  None -0.221016  5.989753e-07   iv
# 14095  None -0.221016  5.989753e-07   iv
# 14271  None -0.218799  7.802537e-07   iv
# 14270  None -0.218799  7.802537e-07   iv
# 13918  None -0.216036  1.080875e-06   iv
# 13919  None -0.216036  1.080875e-06   iv
# 13742  None -0.208115  2.686657e-06   iv
# 13743  None -0.208115  2.686657e-06   iv
# 14238  None -0.204211  4.154967e-06   iv
# 14239  None -0.204211  4.154967e-06   iv
# 13774  None -0.202602  4.961094e-06   iv
# 13775  None -0.202602  4.961094e-06   iv
# 13567  None -0.201943  5.332770e-06   iv
# 13566  None -0.201943  5.332770e-06   iv
# 13391  None -0.200435  6.285088e-06   iv
# 13390  None -0.200435  6.285088e-06   iv
# 13951  None -0.200331  6.356656e-06   iv
# 13950  None -0.200331  6.356656e-06   iv
# 12862  None -0.198363  7.862003e-06   iv
# 12863  None -0.198363  7.862003e-06   iv
