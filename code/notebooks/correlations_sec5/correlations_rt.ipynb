# %% [markdown]
# # Correlations: Information Value and Suprisal vs. Reading Times (Provo, Natural Stories, Brown)

# %%
### Import and utils
import ast
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import spearmanr
from collections import defaultdict, Counter
from scipy.stats import kendalltau, linregress
from tqdm.notebook import tqdm
from typing import List, Dict, Tuple, Optional, Union
from ast import literal_eval
import statsmodels.api as sm
import statsmodels.formula.api as smf


# For local imports
import sys
sys.path.append('../../')
from utils import load_jsonl, load_surprise_data


# Plots
sns.set_context("paper")
sns.set_style("whitegrid")
sns.set_palette("colorblind")
sns.set(font_scale=1.8)

# %% [markdown]
# ## Load data and preprocess

# %%
DATASETS = ['brown', 'ns', 'provo']

DATASET_CONTEXT_MAP = {
    'switchboard': 'switchboard/switchboard_results_is.jsonl',
    'dailydialog': 'dailydialog/dailydialog_results_is.jsonl',
    'BLL2018': 'BLL2018/processed_ratings.jsonl',
    'brown': 'RTs_5jun/brown_rt.jsonl',
    'ns': 'RTs_5jun/ns_rt.jsonl',
    'provo': 'RTs_5jun/provo_rt.jsonl',
}

CORPUS_NAMES = {
    'switchboard': 'Switchboard',
    'dailydialog': 'Dailydialog',
    'BLL2018': 'Clasp',
    'provo': 'Provo',
    'brown': 'Brown',
    'ns': 'Natural Stories',
}

MODEL_NAME_MAP = {
    'gpt2': 'GPT-2 Small',
    'gpt2-ft': 'GPT-2 Small Finetuned', # todo: remove
    'gpt2_medium': 'GPT-2 Medium',
    'gpt2-medium': 'GPT-2 Medium',
    'gpt2_large': 'GPT-2 Large',
    'gpt2-large': 'GPT-2 Large',
    'dialogpt_small': 'DialoGPT Small',
    'dialogpt-small': 'DialoGPT Small',
    'dialogpt_medium': 'DialoGPT Medium',
    'dialogpt-medium': 'DialoGPT Medium',
    'dialogpt_large': 'DialoGPT Large',
    'dialogpt-large': 'DialoGPT Large',
    'opt_125m': 'OPT 125M',
    'opt-125m': 'OPT 125M',
    'opt_350m': 'OPT 350M',
    'opt-350m': 'OPT 350M',
    'opt_1.3b': 'OPT 1.3B',
    'opt-1.3b': 'OPT 1.3B',
    'gpt_neo_125m': 'GPT-Neo 125M',
    'gpt-neo-125m': 'GPT-Neo 125M',
    'gpt_neo_1.3b': 'GPT-Neo 1.3B',
    'gpt-neo-1.3b': 'GPT-Neo 1.3B',
    'gpt-neo-1.3B': 'GPT-Neo 1.3B',
}

SAMPLING_PARAM_MAP = {
    "None": "None", "02": "0.2", "03": "0.3", "075": "0.75", "08": "0.8",
    "085": "0.85", "09": "0.9", "095": "0.95", "125": "1.25"
}

SURPRISAL_COLUMNS = [
    'in_context_surprisal', #'out_of_context_surprisal', 'in_context_surprisal_rnd',
       # 'in_context_entropies', 'out_of_context_entropies', 'in_context_entropies_rnd',
       # 'in_context_deviations', 'out_of_context_deviations', 'in_context_deviations_rnd',
]

# %%
### Load data
dfs = []
for dataset in DATASETS:
    print(f"Loading data for {dataset}...")
    DATA_DIR = f"../../../data/surprise/{dataset}"

    df = load_surprise_data(DATA_DIR)

    # Prettify column and value names
    df["corpus"] = df["corpus"].map(CORPUS_NAMES)
    df["sampling"] = df["sampling"].str.capitalize()
    df["sampling"] = df["sampling"].str.replace("Temp", "Temperature")

    df["model"] = df["model"].map(MODEL_NAME_MAP)

    sampling_param_map = {
        "None": "None", "02": "0.2", "03": "0.3", "075": "0.75", "08": "0.8",
        "085": "0.85", "09": "0.9", "095": "0.95", "125": "1.25"
    }
    df["sampling_param"] = df["sampling_param"].map(sampling_param_map)

    dfs.append(df)

surprise = pd.concat(dfs, axis=0, ignore_index=True)

# Set unique data point id for grouping
surprise["item_id"] = surprise.apply(lambda row: f"{row['context_id']}", axis=1)

# Merge sampling and sampling param column in surprise
surprise['sampling'] = surprise['sampling'].astype(str)
surprise['sampling_param'] = surprise['sampling_param'].astype(str)
surprise['sampling_strategy'] = surprise['sampling'] + '_' + surprise['sampling_param']
# Out:
# Loading data for brown...
# Size of dataset: 396000 rows
# Loading data for ns...
# Size of dataset: 377720 rows
# Loading data for provo...
# Size of dataset: 119680 rows

# %%
POWER_RANGE = np.arange(0.5, 5.01, 0.25)

def local_diff(x):
    """from RUID"""
    d = 0
    for i in range(len(x)-1):
        d += abs(x[i+1]-x[i])
    return d

def power(x, y):
    """from RUID"""
#     if x.mask.all():
#         return np.nan
#     return np.nanmean(x**y)
    return np.nansum(x**y)

def load_surprisal_data(data_dir, columns, surprisal_columns):
    """
    Load data from a directory of CSV files containing surprisal estimates.
    # Arguments:
        data_dir (str): Path to directory containing CSV files.
        columns (list): columns to load from CSV files. If None, all columns are loaded.
        surprisal_columns (list): columns to format with ast (ugly but fine for now)
    """
    data = None
    for file in os.listdir(data_dir):
        if file.endswith(".csv"):
            dset = data_dir.split('/')
            fp = os.path.join(data_dir, file)
            df = pd.read_csv(fp, usecols=columns)

            # Store with fields
            fields_from_name = fp.split('/')
            df['corpus'] = CORPUS_NAMES[fields_from_name[-2]]
            df['model'] = MODEL_NAME_MAP[fields_from_name[-1][:-4]]

            # literal eval
            for column in surprisal_columns:
                df[column] = df[column].apply(
                    lambda s: [
                        ast.literal_eval(x.strip(' []'))
                        for x in s.split() if x.strip(' []')
                    ]
                )

            if "data" in locals():
                data = pd.concat([data, df])
            else:
                data = df

    print(f"Size of dataset: {data.shape} rows, cols")

    # Add sequence surprisal aggregates
    surprise_cols = [c for c in data.columns if "in_" in c or "out_" in c]
    # print(surprise_cols)
    for col in surprise_cols:
        data[f'{col}_agg_sum'] = data[col].apply(np.sum)
        data[f'{col}_agg_variance'] = data[col].apply(np.var)
        data[f'{col}_agg_max'] = data[col].apply(np.amax)
        data[f'{col}_agg_mean'] = data[col].apply(np.mean)
        data[f'{col}_agg_ldiff'] = data[col].apply(local_diff)
        for p in POWER_RANGE:
            data[f'{col}_agg_power_' + str(p).replace('.', '_')] = data[col].apply(lambda x: power(x, p))

    print(f"Size of dataset: {data.shape} rows, cols")
    return data

# %%
# Load the surprisal data
cols = [
    'context_id', 'time_mean_NO'#, 'judgements', 'mean_acceptability', 'median_acceptability', 'real'
]
all_cols = cols + SURPRISAL_COLUMNS

all_surprisal_dfs = []
for dataset in DATASETS:
    print(f"Loading data for {dataset}...")
    DATA_DIR = f"../../../data/surprisal/{dataset}"

    surprisal_df = load_surprisal_data(DATA_DIR, all_cols, SURPRISAL_COLUMNS)
    all_surprisal_dfs.append(surprisal_df)

surprisal = pd.concat(all_surprisal_dfs, axis=0, ignore_index=True)
# Out:
# Loading data for brown...
# Size of dataset: (3600, 5) rows, cols
# Size of dataset: (3600, 29) rows, cols
# Loading data for ns...
# Size of dataset: (3976, 5) rows, cols
# Size of dataset: (3976, 29) rows, cols
# Loading data for provo...
# Size of dataset: (1088, 5) rows, cols
# Size of dataset: (1088, 29) rows, cols

# %%
len(surprise)/len(surprisal)
# Out:
# 103.11634349030471

# %% [markdown]
# ## Measure correlations

# %%
corrs = []
for corpus in tqdm(surprisal.corpus.unique()):
    for model in surprisal.model.unique():
        for measure in SURPRISAL_COLUMNS:
            for agg in ['agg_sum', 'agg_variance', 'agg_max', 'agg_mean', 'agg_ldiff'] + [f"agg_power_{str(p).replace('.', '_')}" for p in POWER_RANGE]:

                _df = surprisal[
                    (surprisal['model'] == model) &
                    (surprisal['corpus'] == corpus)
                ]
                assert(len(_df) == 100, f"Expected 100 rows, got {len(_df)}")

                if measure == 'mutual_info':
                    measure_name = measure
                else:
                    measure_name = f'{measure}_{agg}'

                rho, p = spearmanr(_df[measure_name], _df['time_mean_NO'], nan_policy="omit")

                corrs.append({
                    'corpus': corpus,
                    'model': model,
                    'n_samples': 'None',
                    'sampling': 'None',
                    'measure': measure,
                    'agg': agg,
                    'corr': rho,
                    'p-value': p,
                    'type': 'surprisal'
                })


iv_measures = [
    'surprise_mean_1gram', 'surprise_mean_2gram', 'surprise_mean_3gram',
    'surprise_mean_1gram_pos', 'surprise_mean_2gram_pos', 'surprise_mean_3gram_pos',
    'surprise_mean_cosine', 'surprise_mean_euclidean',
    'surprise_min_1gram', 'surprise_min_2gram', 'surprise_min_3gram',
    'surprise_min_1gram_pos', 'surprise_min_2gram_pos', 'surprise_min_3gram_pos',
    'surprise_min_cosine', 'surprise_min_euclidean'
]

for corpus in surprise.corpus.unique():
    for model in surprise.model.unique():
        print(model)
        for n_samples in tqdm(surprise.n_samples.unique()):
            for sampling in surprise.sampling_strategy.unique():
                for measure in iv_measures:
                    _df = surprise[
                        (surprise['model'] == model) &
                        (surprise['corpus'] == corpus) &
                        (surprise['n_samples'] == n_samples) &
                        (surprise['sampling_strategy'] == sampling)
                    ]
                    assert(len(_df) == 100, f"Expected 100 rows, got {len(_df)}")

                    rho, p = spearmanr(_df[measure], _df['time_mean_NO'], nan_policy="omit")

                    corrs.append({
                        'corpus': corpus,
                        'model': model,
                        'n_samples': n_samples,
                        'sampling': sampling,
                        'measure': measure,
                        'agg': 'None',
                        'corr': rho,
                        'p-value': p,
                        'type': 'iv'
                    })

corrs_df = pd.DataFrame(corrs)
# Out:
# <>:11: SyntaxWarning: assertion is always true, perhaps remove parentheses?
# <>:54: SyntaxWarning: assertion is always true, perhaps remove parentheses?
# <>:11: SyntaxWarning: assertion is always true, perhaps remove parentheses?
# <>:54: SyntaxWarning: assertion is always true, perhaps remove parentheses?
# /var/folders/0s/847v13g104z23kr193w_v2640000gn/T/ipykernel_61046/3560968814.py:11: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(len(_df) == 100, f"Expected 100 rows, got {len(_df)}")
#   0%|          | 0/3 [00:00<?, ?it/s]
# GPT-2 Large
# /var/folders/0s/847v13g104z23kr193w_v2640000gn/T/ipykernel_61046/3560968814.py:54: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(len(_df) == 100, f"Expected 100 rows, got {len(_df)}")
#   0%|          | 0/10 [00:00<?, ?it/s]
# GPT-Neo 125M
#   0%|          | 0/10 [00:00<?, ?it/s]
# GPT-Neo 1.3B
#   0%|          | 0/10 [00:00<?, ?it/s]
# GPT-2 Small
#   0%|          | 0/10 [00:00<?, ?it/s]
# OPT 350M
#   0%|          | 0/10 [00:00<?, ?it/s]
# GPT-2 Medium
#   0%|          | 0/10 [00:00<?, ?it/s]
# OPT 125M
#   0%|          | 0/10 [00:00<?, ?it/s]
# OPT 1.3B
#   0%|          | 0/10 [00:00<?, ?it/s]
# GPT-2 Large
#   0%|          | 0/10 [00:00<?, ?it/s]
# GPT-Neo 125M
#   0%|          | 0/10 [00:00<?, ?it/s]
# GPT-Neo 1.3B
#   0%|          | 0/10 [00:00<?, ?it/s]
# GPT-2 Small
#   0%|          | 0/10 [00:00<?, ?it/s]
# OPT 350M
#   0%|          | 0/10 [00:00<?, ?it/s]
# GPT-2 Medium
#   0%|          | 0/10 [00:00<?, ?it/s]
# OPT 125M
#   0%|          | 0/10 [00:00<?, ?it/s]
# OPT 1.3B
#   0%|          | 0/10 [00:00<?, ?it/s]
# GPT-2 Large
#   0%|          | 0/10 [00:00<?, ?it/s]
# GPT-Neo 125M
#   0%|          | 0/10 [00:00<?, ?it/s]
# GPT-Neo 1.3B
#   0%|          | 0/10 [00:00<?, ?it/s]
# GPT-2 Small
#   0%|          | 0/10 [00:00<?, ?it/s]
# OPT 350M
#   0%|          | 0/10 [00:00<?, ?it/s]
# GPT-2 Medium
#   0%|          | 0/10 [00:00<?, ?it/s]
# OPT 125M
#   0%|          | 0/10 [00:00<?, ?it/s]
# OPT 1.3B
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
# Save dataframe
corrs_df.to_csv("/Users/mario/code/surprise/code/notebooks/correlations/dataframes/correlations_rt.csv", index=False)

# %%
## Show rankings

# %%
corrs_df[
    (corrs_df.corpus == 'Provo') &
    (corrs_df.type == 'iv')
].sort_values('corr', ascending=True).head(20)
# Out:
#       corpus         model n_samples          sampling
# 32793  Provo  GPT-Neo 1.3B        40      Typical_0.95  \
# 33145  Provo  GPT-Neo 1.3B        60      Typical_0.95
# 33977  Provo  GPT-Neo 1.3B       100       Typical_0.3
# 35881  Provo      OPT 350M        10       Nucleus_0.9
# 32617  Provo  GPT-Neo 1.3B        30      Typical_0.95
# 35802  Provo      OPT 350M        10  Temperature_1.25
# 35794  Provo      OPT 350M        10  Temperature_1.25
# 32969  Provo  GPT-Neo 1.3B        50      Typical_0.95
# 39374  Provo      OPT 125M        10      Nucleus_0.85
# 39375  Provo      OPT 125M        10      Nucleus_0.85
# 33801  Provo  GPT-Neo 1.3B        90       Typical_0.3
# 35759  Provo   GPT-2 Small       100    Ancestral_None
# 35758  Provo   GPT-2 Small       100    Ancestral_None
# 32495  Provo  GPT-Neo 1.3B        20  Temperature_0.75
# 32494  Provo  GPT-Neo 1.3B        20  Temperature_0.75
# 39318  Provo      OPT 125M        10  Temperature_1.25
# 33178  Provo  GPT-Neo 1.3B        60       Typical_0.2
# 39319  Provo      OPT 125M        10  Temperature_1.25
# 34654  Provo   GPT-2 Small        40       Nucleus_0.9
# 34655  Provo   GPT-2 Small        40       Nucleus_0.9
#
#                        measure   agg      corr   p-value type
# 32793       surprise_min_2gram  None -0.046230  0.593035   iv
# 33145       surprise_min_2gram  None -0.041634  0.630334   iv
# 33977       surprise_min_2gram  None -0.035625  0.680524   iv
# 35881       surprise_min_2gram  None -0.026317  0.761031   iv
# 32617       surprise_min_2gram  None -0.025358  0.769491   iv
# 35802       surprise_min_3gram  None -0.023986  0.781642   iv
# 35794      surprise_mean_3gram  None -0.023742  0.783804   iv
# 32969       surprise_min_2gram  None -0.016997  0.844293   iv
# 39374      surprise_min_cosine  None -0.013401  0.876942   iv
# 39375   surprise_min_euclidean  None -0.013401  0.876942   iv
# 33801       surprise_min_2gram  None -0.012454  0.885576   iv
# 35759   surprise_min_euclidean  None -0.008869  0.918380   iv
# 35758      surprise_min_cosine  None -0.008869  0.918380   iv
# 32495   surprise_min_euclidean  None -0.008840  0.918642   iv
# 32494      surprise_min_cosine  None -0.008840  0.918642   iv
# 39318     surprise_mean_cosine  None -0.008816  0.918861   iv
# 33178       surprise_min_3gram  None -0.007316  0.932633   iv
# 39319  surprise_mean_euclidean  None -0.006622  0.939012   iv
# 34654      surprise_min_cosine  None -0.006445  0.940635   iv
# 34655   surprise_min_euclidean  None -0.006445  0.940635   iv

# %%
corrs_df[
    (corrs_df.corpus == 'Provo') &
    (corrs_df.type == 'iv')
].sort_values('corr', ascending=False).head(20)
# Out:
#       corpus         model n_samples          sampling
# 34141  Provo   GPT-2 Small        10      Nucleus_0.95  \
# 39429  Provo      OPT 125M        10       Typical_0.3
# 34133  Provo   GPT-2 Small        10      Nucleus_0.95
# 39437  Provo      OPT 125M        10       Typical_0.3
# 38469  Provo  GPT-2 Medium        60  Temperature_0.75
# 39432  Provo      OPT 125M        10       Typical_0.3
# 38645  Provo  GPT-2 Medium        70  Temperature_0.75
# 28829  Provo   GPT-2 Large        10       Nucleus_0.8
# 41805  Provo      OPT 1.3B        50       Typical_0.2
# 38285  Provo  GPT-2 Medium        50       Typical_0.2
# 38733  Provo  GPT-2 Medium        70       Typical_0.3
# 37584  Provo  GPT-2 Medium        10  Temperature_0.75
# 38293  Provo  GPT-2 Medium        50  Temperature_0.75
# 28821  Provo   GPT-2 Large        10       Nucleus_0.8
# 38997  Provo  GPT-2 Medium        90  Temperature_0.75
# 38821  Provo  GPT-2 Medium        80  Temperature_0.75
# 37941  Provo  GPT-2 Medium        30  Temperature_0.75
# 34140  Provo   GPT-2 Small        10      Nucleus_0.95
# 38117  Provo  GPT-2 Medium        40  Temperature_0.75
# 37757  Provo  GPT-2 Medium        20       Typical_0.2
#
#                        measure   agg      corr       p-value type
# 34141   surprise_min_3gram_pos  None  0.420734  3.396050e-07   iv
# 39429  surprise_mean_3gram_pos  None  0.396429  1.773201e-06   iv
# 34133  surprise_mean_3gram_pos  None  0.392141  2.342071e-06   iv
# 39437   surprise_min_3gram_pos  None  0.389302  2.809909e-06   iv
# 38469  surprise_mean_3gram_pos  None  0.382382  4.349235e-06   iv
# 39432       surprise_min_1gram  None  0.379163  5.311087e-06   iv
# 38645  surprise_mean_3gram_pos  None  0.378522  5.525353e-06   iv
# 28829   surprise_min_3gram_pos  None  0.378330  5.591134e-06   iv
# 41805   surprise_min_3gram_pos  None  0.376833  6.129758e-06   iv
# 38285   surprise_min_3gram_pos  None  0.376482  6.263017e-06   iv
# 38733   surprise_min_3gram_pos  None  0.375133  6.800514e-06   iv
# 37584      surprise_mean_1gram  None  0.374863  6.913466e-06   iv
# 38293  surprise_mean_3gram_pos  None  0.369877  9.341753e-06   iv
# 28821  surprise_mean_3gram_pos  None  0.369776  9.398362e-06   iv
# 38997  surprise_mean_3gram_pos  None  0.367921  1.049863e-05   iv
# 38821  surprise_mean_3gram_pos  None  0.367311  1.088667e-05   iv
# 37941  surprise_mean_3gram_pos  None  0.366481  1.143591e-05   iv
# 34140   surprise_min_2gram_pos  None  0.366323  1.154307e-05   iv
# 38117  surprise_mean_3gram_pos  None  0.366314  1.154950e-05   iv
# 37757   surprise_min_3gram_pos  None  0.366049  1.173172e-05   iv

# %%
corrs_df[
    (corrs_df.corpus == 'Provo') &
    (corrs_df.type == 'surprisal')
].sort_values('corr', ascending=False).head(20)
# Out:
#     corpus         model n_samples sampling               measure
# 529  Provo  GPT-Neo 125M      None     None  in_context_surprisal  \
# 385  Provo  GPT-2 Medium      None     None  in_context_surprisal
# 531  Provo  GPT-Neo 125M      None     None  in_context_surprisal
# 387  Provo  GPT-2 Medium      None     None  in_context_surprisal
# 555  Provo      OPT 125M      None     None  in_context_surprisal
# 483  Provo  GPT-Neo 1.3B      None     None  in_context_surprisal
# 459  Provo      OPT 350M      None     None  in_context_surprisal
# 435  Provo   GPT-2 Small      None     None  in_context_surprisal
# 411  Provo      OPT 1.3B      None     None  in_context_surprisal
# 505  Provo   GPT-2 Large      None     None  in_context_surprisal
# 433  Provo   GPT-2 Small      None     None  in_context_surprisal
# 481  Provo  GPT-Neo 1.3B      None     None  in_context_surprisal
# 507  Provo   GPT-2 Large      None     None  in_context_surprisal
# 457  Provo      OPT 350M      None     None  in_context_surprisal
# 553  Provo      OPT 125M      None     None  in_context_surprisal
# 409  Provo      OPT 1.3B      None     None  in_context_surprisal
# 386  Provo  GPT-2 Medium      None     None  in_context_surprisal
# 407  Provo  GPT-2 Medium      None     None  in_context_surprisal
# 406  Provo  GPT-2 Medium      None     None  in_context_surprisal
# 405  Provo  GPT-2 Medium      None     None  in_context_surprisal
#
#                 agg      corr       p-value       type
# 529    agg_variance  0.495325  8.758864e-10  surprisal
# 385    agg_variance  0.481103  3.054629e-09  surprisal
# 531        agg_mean  0.470908  7.225927e-09  surprisal
# 387        agg_mean  0.459153  1.884242e-08  surprisal
# 555        agg_mean  0.458556  1.976230e-08  surprisal
# 483        agg_mean  0.454525  2.721084e-08  surprisal
# 459        agg_mean  0.448857  4.236598e-08  surprisal
# 435        agg_mean  0.446167  5.212939e-08  surprisal
# 411        agg_mean  0.445861  5.336466e-08  surprisal
# 505    agg_variance  0.441248  7.580989e-08  surprisal
# 433    agg_variance  0.440814  7.833546e-08  surprisal
# 481    agg_variance  0.431253  1.593692e-07  surprisal
# 507        agg_mean  0.425175  2.475228e-07  surprisal
# 457    agg_variance  0.419932  3.593994e-07  surprisal
# 553    agg_variance  0.376738  6.165515e-06  surprisal
# 409    agg_variance  0.304122  3.187661e-04  surprisal
# 386         agg_max  0.226764  7.936331e-03  surprisal
# 407   agg_power_5_0  0.219665  1.018360e-02  surprisal
# 406  agg_power_4_75  0.215839  1.161336e-02  surprisal
# 405   agg_power_4_5  0.214274  1.224705e-02  surprisal

# %%
corrs_df[
    (corrs_df.corpus == 'Natural Stories') &
    (corrs_df.type == 'iv')
].sort_values('corr', ascending=False).head(20)
# Out:
#                 corpus         model n_samples          sampling
# 17153  Natural Stories  GPT-Neo 125M        50       Typical_0.2  \
# 16977  Natural Stories  GPT-Neo 125M        40       Typical_0.2
# 17505  Natural Stories  GPT-Neo 125M        70       Typical_0.2
# 18192  Natural Stories  GPT-Neo 1.3B        10  Temperature_1.25
# 18033  Natural Stories  GPT-Neo 125M       100       Typical_0.2
# 18368  Natural Stories  GPT-Neo 1.3B        20  Temperature_1.25
# 17488  Natural Stories  GPT-Neo 125M        70  Temperature_1.25
# 17329  Natural Stories  GPT-Neo 125M        60       Typical_0.2
# 16608  Natural Stories  GPT-Neo 125M        20  Temperature_1.25
# 17857  Natural Stories  GPT-Neo 125M        90       Typical_0.2
# 17681  Natural Stories  GPT-Neo 125M        80       Typical_0.2
# 17856  Natural Stories  GPT-Neo 125M        90       Typical_0.2
# 17312  Natural Stories  GPT-Neo 125M        60  Temperature_1.25
# 26289  Natural Stories      OPT 125M        70  Temperature_1.25
# 26465  Natural Stories      OPT 125M        80  Temperature_1.25
# 25585  Natural Stories      OPT 125M        30  Temperature_1.25
# 17680  Natural Stories  GPT-Neo 125M        80       Typical_0.2
# 18032  Natural Stories  GPT-Neo 125M       100       Typical_0.2
# 26641  Natural Stories      OPT 125M        90  Temperature_1.25
# 17504  Natural Stories  GPT-Neo 125M        70       Typical_0.2
#
#                    measure   agg      corr       p-value type
# 17153  surprise_mean_2gram  None  0.309871  1.602066e-12   iv
# 16977  surprise_mean_2gram  None  0.307502  2.408093e-12   iv
# 17505  surprise_mean_2gram  None  0.306789  2.720287e-12   iv
# 18192  surprise_mean_1gram  None  0.305824  3.206338e-12   iv
# 18033  surprise_mean_2gram  None  0.304159  4.252988e-12   iv
# 18368  surprise_mean_1gram  None  0.304127  4.276135e-12   iv
# 17488  surprise_mean_1gram  None  0.303965  4.394579e-12   iv
# 17329  surprise_mean_2gram  None  0.303740  4.564679e-12   iv
# 16608  surprise_mean_1gram  None  0.302789  5.357964e-12   iv
# 17857  surprise_mean_2gram  None  0.302758  5.385915e-12   iv
# 17681  surprise_mean_2gram  None  0.302386  5.733634e-12   iv
# 17856  surprise_mean_1gram  None  0.298970  1.013663e-11   iv
# 17312  surprise_mean_1gram  None  0.298325  1.127937e-11   iv
# 26289  surprise_mean_2gram  None  0.297824  1.225072e-11   iv
# 26465  surprise_mean_2gram  None  0.297699  1.250701e-11   iv
# 25585  surprise_mean_2gram  None  0.296957  1.413343e-11   iv
# 17680  surprise_mean_1gram  None  0.296637  1.489581e-11   iv
# 18032  surprise_mean_1gram  None  0.296283  1.578548e-11   iv
# 26641  surprise_mean_2gram  None  0.295983  1.658084e-11   iv
# 17504  surprise_mean_1gram  None  0.295591  1.768214e-11   iv

# %%
corrs_df[
    (corrs_df.corpus == 'Natural Stories') &
    (corrs_df.type == 'surprisal')
].sort_values('corr', ascending=False).head(20)
# Out:
#               corpus         model n_samples sampling               measure
# 339  Natural Stories  GPT-Neo 125M      None     None  in_context_surprisal  \
# 291  Natural Stories  GPT-Neo 1.3B      None     None  in_context_surprisal
# 243  Natural Stories   GPT-2 Small      None     None  in_context_surprisal
# 315  Natural Stories   GPT-2 Large      None     None  in_context_surprisal
# 195  Natural Stories  GPT-2 Medium      None     None  in_context_surprisal
# 363  Natural Stories      OPT 125M      None     None  in_context_surprisal
# 267  Natural Stories      OPT 350M      None     None  in_context_surprisal
# 219  Natural Stories      OPT 1.3B      None     None  in_context_surprisal
# 337  Natural Stories  GPT-Neo 125M      None     None  in_context_surprisal
# 289  Natural Stories  GPT-Neo 1.3B      None     None  in_context_surprisal
# 241  Natural Stories   GPT-2 Small      None     None  in_context_surprisal
# 313  Natural Stories   GPT-2 Large      None     None  in_context_surprisal
# 193  Natural Stories  GPT-2 Medium      None     None  in_context_surprisal
# 338  Natural Stories  GPT-Neo 125M      None     None  in_context_surprisal
# 359  Natural Stories  GPT-Neo 125M      None     None  in_context_surprisal
# 217  Natural Stories      OPT 1.3B      None     None  in_context_surprisal
# 358  Natural Stories  GPT-Neo 125M      None     None  in_context_surprisal
# 357  Natural Stories  GPT-Neo 125M      None     None  in_context_surprisal
# 356  Natural Stories  GPT-Neo 125M      None     None  in_context_surprisal
# 355  Natural Stories  GPT-Neo 125M      None     None  in_context_surprisal
#
#                 agg      corr       p-value       type
# 339        agg_mean  0.392923  8.516890e-20  surprisal
# 291        agg_mean  0.390716  1.419814e-19  surprisal
# 243        agg_mean  0.379489  1.802647e-18  surprisal
# 315        agg_mean  0.371750  9.822118e-18  surprisal
# 195        agg_mean  0.360891  9.827840e-17  surprisal
# 363        agg_mean  0.322905  1.593011e-13  surprisal
# 267        agg_mean  0.302556  5.572388e-12  surprisal
# 219        agg_mean  0.295432  1.814631e-11  surprisal
# 337    agg_variance  0.232546  1.577692e-07  surprisal
# 289    agg_variance  0.230097  2.142759e-07  surprisal
# 241    agg_variance  0.180519  5.175120e-05  surprisal
# 313    agg_variance  0.164692  2.264477e-04  surprisal
# 193    agg_variance  0.159889  3.454965e-04  surprisal
# 338         agg_max  0.041756  3.529138e-01  surprisal
# 359   agg_power_5_0  0.040607  3.663306e-01  surprisal
# 217    agg_variance  0.039380  3.810070e-01  surprisal
# 358  agg_power_4_75  0.037936  3.987271e-01  surprisal
# 357   agg_power_4_5  0.035556  4.289855e-01  surprisal
# 356  agg_power_4_25  0.033227  4.598494e-01  surprisal
# 355   agg_power_4_0  0.027787  5.365518e-01  surprisal

# %%
corrs_df[
    (corrs_df.corpus == 'Brown') &
    (corrs_df.type == 'iv')
].sort_values('corr', ascending=False).head(80)
# Out:
#       corpus         model n_samples          sampling
# 7401   Brown   GPT-2 Small        90       Typical_0.3  \
# 3017   Brown  GPT-Neo 125M        40    Ancestral_None
# 7577   Brown   GPT-2 Small       100       Typical_0.3
# 6873   Brown   GPT-2 Small        60       Typical_0.3
# 7225   Brown   GPT-2 Small        80       Typical_0.3
# ...      ...           ...       ...               ...
# 11433  Brown      OPT 125M        20      Nucleus_0.95
# 10377  Brown  GPT-2 Medium        60      Nucleus_0.95
# 1161   Brown   GPT-2 Large        40  Temperature_0.75
# 7977   Brown      OPT 350M        30      Typical_0.95
# 6139   Brown   GPT-2 Small        20       Nucleus_0.9
#
#                       measure   agg      corr   p-value type
# 7401       surprise_min_2gram  None  0.223212  0.000002   iv
# 3017       surprise_min_2gram  None  0.221030  0.000002   iv
# 7577       surprise_min_2gram  None  0.220205  0.000002   iv
# 6873       surprise_min_2gram  None  0.218814  0.000003   iv
# 7225       surprise_min_2gram  None  0.206637  0.000010   iv
# ...                       ...   ...       ...       ...  ...
# 11433      surprise_min_2gram  None  0.174542  0.000199   iv
# 10377      surprise_min_2gram  None  0.174460  0.000200   iv
# 1161       surprise_min_2gram  None  0.174305  0.000203   iv
# 7977       surprise_min_2gram  None  0.173933  0.000209   iv
# 6139   surprise_min_1gram_pos  None  0.173822  0.000211   iv
#
# [80 rows x 9 columns]

# %%
corrs_df[
    (corrs_df.corpus == 'Brown') &
    (corrs_df.type == 'surprisal')
].sort_values('corr', ascending=False).head(20)
# Out:
#     corpus         model n_samples sampling               measure
# 99   Brown  GPT-Neo 1.3B      None     None  in_context_surprisal  \
# 51   Brown   GPT-2 Small      None     None  in_context_surprisal
# 147  Brown  GPT-Neo 125M      None     None  in_context_surprisal
# 3    Brown  GPT-2 Medium      None     None  in_context_surprisal
# 123  Brown   GPT-2 Large      None     None  in_context_surprisal
# 171  Brown      OPT 125M      None     None  in_context_surprisal
# 75   Brown      OPT 350M      None     None  in_context_surprisal
# 170  Brown      OPT 125M      None     None  in_context_surprisal
# 27   Brown      OPT 1.3B      None     None  in_context_surprisal
# 74   Brown      OPT 350M      None     None  in_context_surprisal
# 191  Brown      OPT 125M      None     None  in_context_surprisal
# 190  Brown      OPT 125M      None     None  in_context_surprisal
# 189  Brown      OPT 125M      None     None  in_context_surprisal
# 188  Brown      OPT 125M      None     None  in_context_surprisal
# 95   Brown      OPT 350M      None     None  in_context_surprisal
# 94   Brown      OPT 350M      None     None  in_context_surprisal
# 187  Brown      OPT 125M      None     None  in_context_surprisal
# 169  Brown      OPT 125M      None     None  in_context_surprisal
# 93   Brown      OPT 350M      None     None  in_context_surprisal
# 186  Brown      OPT 125M      None     None  in_context_surprisal
#
#                 agg      corr   p-value       type
# 99         agg_mean  0.219881  0.000002  surprisal
# 51         agg_mean  0.216187  0.000004  surprisal
# 147        agg_mean  0.212365  0.000006  surprisal
# 3          agg_mean  0.199709  0.000020  surprisal
# 123        agg_mean  0.193166  0.000037  surprisal
# 171        agg_mean  0.188270  0.000059  surprisal
# 75         agg_mean  0.163418  0.000501  surprisal
# 170         agg_max  0.149453  0.001476  surprisal
# 27         agg_mean  0.146486  0.001836  surprisal
# 74          agg_max  0.134265  0.004328  surprisal
# 191   agg_power_5_0  0.126189  0.007359  surprisal
# 190  agg_power_4_75  0.123276  0.008850  surprisal
# 189   agg_power_4_5  0.120358  0.010607  surprisal
# 188  agg_power_4_25  0.117563  0.012574  surprisal
# 95    agg_power_5_0  0.116651  0.013282  surprisal
# 94   agg_power_4_75  0.114907  0.014734  surprisal
# 187   agg_power_4_0  0.114073  0.015476  surprisal
# 169    agg_variance  0.113385  0.016113  surprisal
# 93    agg_power_4_5  0.113121  0.016364  surprisal
# 186  agg_power_3_75  0.110663  0.018864  surprisal

# %% [markdown]
# ## Find best estimator per corpus and linguistic level

# %%
corrs_df[
    (corrs_df.corpus == 'Provo') &
    (corrs_df.type == "iv") &
    (~corrs_df.measure.str.contains('cosine')) &
    (~corrs_df.measure.str.contains('euclidean')) &
    (~corrs_df.measure.str.contains('pos'))
].sort_values('corr', ascending=False).head(2)
# Out:
#       corpus         model n_samples          sampling              measure
# 39432  Provo      OPT 125M        10       Typical_0.3   surprise_min_1gram  \
# 37584  Provo  GPT-2 Medium        10  Temperature_0.75  surprise_mean_1gram
#
#         agg      corr   p-value type
# 39432  None  0.379163  0.000005   iv
# 37584  None  0.374863  0.000007   iv

# %%
corrs_df[
    (corrs_df.corpus == 'Provo') &
    (corrs_df.type == "iv") &
    (corrs_df.measure.str.contains('pos'))
].sort_values('corr', ascending=False).head(2)
# Out:
#       corpus        model n_samples      sampling                  measure
# 34141  Provo  GPT-2 Small        10  Nucleus_0.95   surprise_min_3gram_pos  \
# 39429  Provo     OPT 125M        10   Typical_0.3  surprise_mean_3gram_pos
#
#         agg      corr       p-value type
# 34141  None  0.420734  3.396050e-07   iv
# 39429  None  0.396429  1.773201e-06   iv

# %%
corrs_df[
    (corrs_df.corpus == 'Provo') &
    (corrs_df.type == "iv") &
    (corrs_df.measure.str.contains('cosine') | corrs_df.measure.str.contains('euclidean'))
].sort_values('corr', ascending=False).head(2)
# Out:
#       corpus     model n_samples      sampling                 measure   agg
# 41007  Provo  OPT 125M       100  Nucleus_0.95  surprise_min_euclidean  None  \
# 41006  Provo  OPT 125M       100  Nucleus_0.95     surprise_min_cosine  None
#
#            corr   p-value type
# 41007  0.181198  0.034762   iv
# 41006  0.181198  0.034762   iv

# %%
corrs_df[
    (corrs_df.corpus == 'Natural Stories') &
    (corrs_df.type == "iv") &
    (~corrs_df.measure.str.contains('cosine')) &
    (~corrs_df.measure.str.contains('euclidean')) &
    (~corrs_df.measure.str.contains('pos'))
].sort_values('corr', ascending=False).head(2)
# Out:
#                 corpus         model n_samples     sampling
# 17153  Natural Stories  GPT-Neo 125M        50  Typical_0.2  \
# 16977  Natural Stories  GPT-Neo 125M        40  Typical_0.2
#
#                    measure   agg      corr       p-value type
# 17153  surprise_mean_2gram  None  0.309871  1.602066e-12   iv
# 16977  surprise_mean_2gram  None  0.307502  2.408093e-12   iv

# %%
corrs_df[
    (corrs_df.corpus == 'Natural Stories') &
    (corrs_df.type == "iv") &
    (corrs_df.measure.str.contains('pos'))
].sort_values('corr', ascending=False).head(2)
# Out:
#                 corpus         model n_samples     sampling
# 16507  Natural Stories  GPT-Neo 125M        10  Nucleus_0.8  \
# 25707  Natural Stories      OPT 125M        30  Typical_0.3
#
#                       measure   agg      corr       p-value type
# 16507  surprise_min_1gram_pos  None  0.261986  3.033707e-09   iv
# 25707  surprise_min_1gram_pos  None  0.259018  4.623416e-09   iv

# %%
corrs_df[
    (corrs_df.corpus == 'Natural Stories') &
    (corrs_df.type == "iv") &
    (corrs_df.measure.str.contains('cosine') | corrs_df.measure.str.contains('euclidean'))
].sort_values('corr', ascending=False).head(2)
# Out:
#                 corpus     model n_samples     sampling
# 23391  Natural Stories  OPT 350M       100  Nucleus_0.9  \
# 23390  Natural Stories  OPT 350M       100  Nucleus_0.9
#
#                       measure   agg      corr   p-value type
# 23391  surprise_min_euclidean  None  0.147226  0.000995   iv
# 23390     surprise_min_cosine  None  0.147226  0.000995   iv

# %%
corrs_df[
    (corrs_df.corpus == 'Brown') &
    (corrs_df.type == "iv") &
    (~corrs_df.measure.str.contains('cosine')) &
    (~corrs_df.measure.str.contains('euclidean')) &
    (~corrs_df.measure.str.contains('pos'))
].sort_values('corr', ascending=False).head(2)
# Out:
#      corpus         model n_samples        sampling             measure   agg
# 7401  Brown   GPT-2 Small        90     Typical_0.3  surprise_min_2gram  None  \
# 3017  Brown  GPT-Neo 125M        40  Ancestral_None  surprise_min_2gram  None
#
#           corr   p-value type
# 7401  0.223212  0.000002   iv
# 3017  0.221030  0.000002   iv

# %%
corrs_df[
    (corrs_df.corpus == 'Brown') &
    (corrs_df.type == "iv") &
    (corrs_df.measure.str.contains('pos'))
].sort_values('corr', ascending=False).head(2)
# Out:
#       corpus         model n_samples     sampling                  measure
# 9509   Brown  GPT-2 Medium        10  Typical_0.3  surprise_mean_3gram_pos  \
# 10827  Brown  GPT-2 Medium        90  Typical_0.2   surprise_min_1gram_pos
#
#         agg      corr   p-value type
# 9509   None  0.184840  0.000086   iv
# 10827  None  0.175202  0.000188   iv

# %%
corrs_df[
    (corrs_df.corpus == 'Brown') &
    (corrs_df.type == "iv") &
    (corrs_df.measure.str.contains('cosine') | corrs_df.measure.str.contains('euclidean'))
].sort_values('corr', ascending=False).head(2)
# Out:
#      corpus         model n_samples      sampling                 measure
# 4046  Brown  GPT-Neo 125M       100  Nucleus_0.95     surprise_min_cosine  \
# 4047  Brown  GPT-Neo 125M       100  Nucleus_0.95  surprise_min_euclidean
#
#        agg      corr   p-value type
# 4046  None  0.048443  0.305186   iv
# 4047  None  0.048443  0.305186   iv
