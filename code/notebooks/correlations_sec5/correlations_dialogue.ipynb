# %% [raw]
#     #%% md
#     # Correlations: Information Value and Suprisal vs. Acceptability (Switchboard and DailyDialog)

# %%
### Import and utils
import ast
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import spearmanr
from collections import defaultdict, Counter
from scipy.stats import kendalltau, linregress
from tqdm.notebook import tqdm
from typing import List, Dict, Tuple, Optional, Union
from ast import literal_eval
import statsmodels.api as sm
import statsmodels.formula.api as smf


# For local imports
import sys
sys.path.append('../../')
from utils import load_jsonl, load_surprise_data


# Plots
sns.set_context("paper")
sns.set_style("whitegrid")
sns.set_palette("colorblind")
sns.set(font_scale=1.8)

# %% [markdown]
# ## Load data and preprocess

# %%
DATASETS = ['dailydialog', 'switchboard']

DATASET_CONTEXT_MAP = {
    'switchboard': 'switchboard/switchboard_results_is.jsonl',
    'dailydialog': 'dailydialog/dailydialog_results_is.jsonl',
    'BLL2018': 'BLL2018/processed_ratings.jsonl',
    'brown': 'RTs/brown_rt.jsonl',
    'ns': 'RTs/ns_rt.jsonl',
    'provo': 'RTs/provo_rt.jsonl',
}

CORPUS_NAMES = {
    'switchboard': 'Switchboard',
    'dailydialog': 'Dailydialog',
    'BLL2018': 'Clasp',
    'provo': 'Provo',
    'brown': 'Brown',
    'ns': 'Natural Stories',
}

MODEL_NAME_MAP = {
    'gpt2': 'GPT-2 Small',
    'gpt2-ft': 'GPT-2 Small Finetuned', # todo: remove
    'gpt2_medium': 'GPT-2 Medium',
    'gpt2-medium': 'GPT-2 Medium',
    'gpt2_large': 'GPT-2 Large',
    'gpt2-large': 'GPT-2 Large',
    'dialogpt_small': 'DialoGPT Small',
    'dialogpt-small': 'DialoGPT Small',
    'dialogpt_medium': 'DialoGPT Medium',
    'dialogpt-medium': 'DialoGPT Medium',
    'dialogpt_large': 'DialoGPT Large',
    'dialogpt-large': 'DialoGPT Large',
    'opt_125m': 'OPT 125M',
    'opt-125m': 'OPT 125M',
    'opt_350m': 'OPT 350M',
    'opt-350m': 'OPT 350M',
    'opt_1.3b': 'OPT 1.3B',
    'opt-1.3b': 'OPT 1.3B',
    'gpt_neo_125m': 'GPT-Neo 125M',
    'gpt-neo-125m': 'GPT-Neo 125M',
    'gpt_neo_1.3b': 'GPT-Neo 1.3B',
    'gpt-neo-1.3b': 'GPT-Neo 1.3B',
    'gpt-neo-1.3B': 'GPT-Neo 1.3B',
}

SAMPLING_PARAM_MAP = {
    "None": "None", "02": "0.2", "03": "0.3", "075": "0.75", "08": "0.8",
    "085": "0.85", "09": "0.9", "095": "0.95", "125": "1.25"
}

SURPRISAL_COLUMNS = [
    'in_context_surprisal', # 'out_of_context_surprisal', 'in_context_surprisal_rnd',
       # 'in_context_entropies', 'out_of_context_entropies', 'in_context_entropies_rnd',
       # 'in_context_deviations', 'out_of_context_deviations', 'in_context_deviations_rnd',
]

# %%
dfs = []
for dataset in DATASETS:
    print(f"Loading data for {dataset}...")
    DATA_DIR = f"../../../data/surprise/{dataset}"

    df = load_surprise_data(DATA_DIR)

    # Prettify column and value names
    df["corpus"] = df["corpus"].map(CORPUS_NAMES)
    df["sampling"] = df["sampling"].str.capitalize()
    df["sampling"] = df["sampling"].str.replace("Temp", "Temperature")

    df["model"] = df["model"].map(MODEL_NAME_MAP)

    sampling_param_map = {
        "None": "None", "02": "0.2", "03": "0.3", "075": "0.75", "08": "0.8",
        "085": "0.85", "09": "0.9", "095": "0.95", "125": "1.25"
    }
    df["sampling_param"] = df["sampling_param"].map(sampling_param_map)

    dfs.append(df)

surprise = pd.concat(dfs, axis=0, ignore_index=True)

# Merge sampling and sampling param column in surprise
surprise['sampling'] = surprise['sampling'].astype(str)
surprise['sampling_param'] = surprise['sampling_param'].astype(str)
surprise['sampling_strategy'] = surprise['sampling'] + '_' + surprise['sampling_param']
# Out:
# Loading data for dailydialog...
# Size of dataset: 88000 rows
# Loading data for switchboard...
# Size of dataset: 88000 rows

# %%
POWER_RANGE = np.arange(0.5, 5.01, 0.25)

def local_diff(x):
    """from RUID"""
    d = 0
    for i in range(len(x)-1):
        d += abs(x[i+1]-x[i])
    return d

def power(x, y):
    """from RUID"""
#     if x.mask.all():
#         return np.nan
#     return np.nanmean(x**y)
    return np.nansum(x**y)

def load_surprisal_data(data_dir, columns, surprisal_columns):
    """
    Load data from a directory of CSV files containing surprisal estimates.
    # Arguments:
        data_dir (str): Path to directory containing CSV files.
        columns (list): columns to load from CSV files. If None, all columns are loaded.
        surprisal_columns (list): columns to format with ast (ugly but fine for now)
    """
    data = None
    for file in os.listdir(data_dir):
        if file.endswith(".csv"):
            dset = data_dir.split('/')
            fp = os.path.join(data_dir, file)
            df = pd.read_csv(fp, usecols=columns)

            # Store with fields
            fields_from_name = fp.split('/')
            df['corpus'] = CORPUS_NAMES[fields_from_name[-2]]
            df['model'] = MODEL_NAME_MAP[fields_from_name[-1][:-4]]

            # literal eval
            for column in surprisal_columns:
                df[column] = df[column].apply(
                    lambda s: [
                        ast.literal_eval(x.strip(' []'))
                        for x in s.split() if x.strip(' []')
                    ]
                )

            if "data" in locals():
                data = pd.concat([data, df])
            else:
                data = df

    print(f"Size of dataset: {data.shape} rows, cols")

    # Add sequence surprisal aggregates
    surprise_cols = [c for c in data.columns if ("in_" in c or "out_" in c) and "acceptability" not in c]
    # print(surprise_cols)
    for col in surprise_cols:
        try:
            data[f'{col}_agg_sum'] = data[col].apply(np.sum)
            data[f'{col}_agg_variance'] = data[col].apply(np.var)
            data[f'{col}_agg_max'] = data[col].apply(np.amax)
            data[f'{col}_agg_mean'] = data[col].apply(np.mean)
            data[f'{col}_agg_ldiff'] = data[col].apply(local_diff)
        except TypeError:
            print(f"TypeError for {col}")
            print(data[col].head())
        for p in POWER_RANGE:
            data[f'{col}_agg_power_' + str(p).replace('.', '_')] = data[col].apply(lambda x: power(x, p))

    print(f"Size of dataset: {data.shape} rows, cols")
    return data

# %%
# cols = ['context_id', 'random_context_id', 'time_sum_mean', 'time_sum_list',
       # 'time_count_nonzero', 'time_mean', 'time_sum_mean_NO',
       # 'time_sum_list_NO', 'time_count_nonzero_NO', 'time_mean_NO',]

all_surprisal_dfs = []
for dataset in DATASETS:
    print(f"Loading data for {dataset}...")
    DATA_DIR = f"../../../data/surprisal/{dataset}"

    all_cols = ['context_id', 'target_id', 'mean_acceptability']
    all_cols += SURPRISAL_COLUMNS

    surprisal_df = load_surprisal_data(DATA_DIR, all_cols, SURPRISAL_COLUMNS)
    all_surprisal_dfs.append(surprisal_df)

surprisal = pd.concat(all_surprisal_dfs, axis=0, ignore_index=True)

# surprisal['mutual_info'] = surprisal['in_context_surprisal_agg_mean'] - surprisal['out_of_context_surprisal_agg_mean']
# Out:
# Loading data for dailydialog...
# Size of dataset: (800, 6) rows, cols
# Size of dataset: (800, 30) rows, cols
# Loading data for switchboard...
# Size of dataset: (800, 6) rows, cols
# Size of dataset: (800, 30) rows, cols

# %%
len(surprise)/len(surprisal)
# Out:
# 110.0

# %% [markdown]
# ## Measure correlations

# %%
corrs = []
for corpus in tqdm(surprisal.corpus.unique()):
    for model in surprisal.model.unique():
        for measure in SURPRISAL_COLUMNS:
            for agg in ['agg_sum', 'agg_variance', 'agg_max', 'agg_mean', 'agg_ldiff'] + [f"agg_power_{str(p).replace('.', '_')}" for p in POWER_RANGE]:

                _df = surprisal[
                    (surprisal['model'] == model) &
                    (surprisal['corpus'] == corpus)
                ]
                assert(len(_df) == 100, f"Expected 100 rows, got {len(_df)}")

                if measure == 'mutual_info':
                    measure_name = measure
                else:
                    measure_name = f'{measure}_{agg}'

                rho, p = spearmanr(_df[measure_name], _df['mean_acceptability'], nan_policy="omit")

                corrs.append({
                    'corpus': corpus,
                    'model': model,
                    'n_samples': 'None',
                    'sampling': 'None',
                    'measure': measure,
                    'agg': agg,
                    'corr': rho,
                    'p-value': p,
                    'type': 'surprisal'
                })


iv_measures = [
    'surprise_mean_1gram', 'surprise_mean_2gram', 'surprise_mean_3gram',
    'surprise_mean_1gram_pos', 'surprise_mean_2gram_pos', 'surprise_mean_3gram_pos',
    'surprise_mean_cosine', 'surprise_mean_euclidean',
    'surprise_min_1gram', 'surprise_min_2gram', 'surprise_min_3gram',
    'surprise_min_1gram_pos', 'surprise_min_2gram_pos', 'surprise_min_3gram_pos',
    'surprise_min_cosine', 'surprise_min_euclidean'
]

for corpus in surprise.corpus.unique():
    for model in surprise.model.unique():
        print(model)
        for n_samples in tqdm(surprise.n_samples.unique()):
            for sampling in surprise.sampling_strategy.unique():
                for measure in iv_measures:
                    _df = surprise[
                        (surprise['model'] == model) &
                        (surprise['corpus'] == corpus) &
                        (surprise['n_samples'] == n_samples) &
                        (surprise['sampling_strategy'] == sampling)
                    ]
                    assert(len(_df) == 100, f"Expected 100 rows, got {len(_df)}")

                    rho, p = spearmanr(_df[measure], _df['mean_acceptability'], nan_policy="omit")

                    corrs.append({
                        'corpus': corpus,
                        'model': model,
                        'n_samples': n_samples,
                        'sampling': sampling,
                        'measure': measure,
                        'agg': 'None',
                        'corr': rho,
                        'p-value': p,
                        'type': 'iv'
                    })

corrs_df = pd.DataFrame(corrs)

# %%
corrs_df.to_csv("/Users/mario/code/surprise/code/notebooks/correlations/dataframes/correlations_dialogue.csv", index=False)

# %% [markdown]
# ## Show rankings

# %%
corrs_df[
    (corrs_df.corpus == 'Switchboard') &
    (corrs_df.type == 'surprisal')
].sort_values('corr', ascending=True).head(30)
# Out:
#           corpus           model n_samples sampling               measure
# 211  Switchboard    GPT-2 Medium      None     None  in_context_surprisal  \
# 212  Switchboard    GPT-2 Medium      None     None  in_context_surprisal
# 213  Switchboard    GPT-2 Medium      None     None  in_context_surprisal
# 210  Switchboard    GPT-2 Medium      None     None  in_context_surprisal
# 214  Switchboard    GPT-2 Medium      None     None  in_context_surprisal
# 280  Switchboard     GPT-2 Large      None     None  in_context_surprisal
# 281  Switchboard     GPT-2 Large      None     None  in_context_surprisal
# 282  Switchboard     GPT-2 Large      None     None  in_context_surprisal
# 209  Switchboard    GPT-2 Medium      None     None  in_context_surprisal
# 283  Switchboard     GPT-2 Large      None     None  in_context_surprisal
# 215  Switchboard    GPT-2 Medium      None     None  in_context_surprisal
# 284  Switchboard     GPT-2 Large      None     None  in_context_surprisal
# 279  Switchboard     GPT-2 Large      None     None  in_context_surprisal
# 208  Switchboard    GPT-2 Medium      None     None  in_context_surprisal
# 278  Switchboard     GPT-2 Large      None     None  in_context_surprisal
# 259  Switchboard    GPT-Neo 1.3B      None     None  in_context_surprisal
# 260  Switchboard    GPT-Neo 1.3B      None     None  in_context_surprisal
# 285  Switchboard     GPT-2 Large      None     None  in_context_surprisal
# 261  Switchboard    GPT-Neo 1.3B      None     None  in_context_surprisal
# 258  Switchboard    GPT-Neo 1.3B      None     None  in_context_surprisal
# 286  Switchboard     GPT-2 Large      None     None  in_context_surprisal
# 263  Switchboard    GPT-Neo 1.3B      None     None  in_context_surprisal
# 257  Switchboard    GPT-Neo 1.3B      None     None  in_context_surprisal
# 262  Switchboard    GPT-Neo 1.3B      None     None  in_context_surprisal
# 207  Switchboard    GPT-2 Medium      None     None  in_context_surprisal
# 378  Switchboard  DialoGPT Large      None     None  in_context_surprisal
# 377  Switchboard  DialoGPT Large      None     None  in_context_surprisal
# 287  Switchboard     GPT-2 Large      None     None  in_context_surprisal
# 277  Switchboard     GPT-2 Large      None     None  in_context_surprisal
# 255  Switchboard    GPT-Neo 1.3B      None     None  in_context_surprisal
#
#                 agg      corr       p-value       type
# 211   agg_power_4_0 -0.505806  7.962361e-08  surprisal
# 212  agg_power_4_25 -0.505067  8.375239e-08  surprisal
# 213   agg_power_4_5 -0.501352  1.077773e-07  surprisal
# 210  agg_power_3_75 -0.499512  1.219779e-07  surprisal
# 214  agg_power_4_75 -0.499368  1.231640e-07  surprisal
# 280  agg_power_3_25 -0.499284  1.238610e-07  surprisal
# 281   agg_power_3_5 -0.495274  1.617825e-07  surprisal
# 282  agg_power_3_75 -0.493681  1.797245e-07  surprisal
# 209   agg_power_3_5 -0.493543  1.813680e-07  surprisal
# 283   agg_power_4_0 -0.493224  1.852099e-07  surprisal
# 215   agg_power_5_0 -0.491673  2.050439e-07  surprisal
# 284  agg_power_4_25 -0.487616  2.669407e-07  surprisal
# 279   agg_power_3_0 -0.485061  3.146264e-07  surprisal
# 208  agg_power_3_25 -0.484436  3.274721e-07  surprisal
# 278  agg_power_2_75 -0.482139  3.790651e-07  surprisal
# 259   agg_power_4_0 -0.480937  4.090686e-07  surprisal
# 260  agg_power_4_25 -0.479254  4.548831e-07  surprisal
# 285   agg_power_4_5 -0.479109  4.590290e-07  surprisal
# 261   agg_power_4_5 -0.476783  5.310422e-07  surprisal
# 258  agg_power_3_75 -0.476549  5.388664e-07  surprisal
# 286  agg_power_4_75 -0.475184  5.866240e-07  surprisal
# 263   agg_power_5_0 -0.473374  6.561684e-07  surprisal
# 257   agg_power_3_5 -0.472689  6.844949e-07  surprisal
# 262  agg_power_4_75 -0.471974  7.152991e-07  surprisal
# 207   agg_power_3_0 -0.471415  7.402835e-07  surprisal
# 378  agg_power_3_75 -0.468331  8.936609e-07  surprisal
# 377   agg_power_3_5 -0.467429  9.439150e-07  surprisal
# 287   agg_power_5_0 -0.466912  9.739234e-07  surprisal
# 277   agg_power_2_5 -0.463768  1.176807e-06  surprisal
# 255   agg_power_3_0 -0.462987  1.233121e-06  surprisal

# %%
corrs_df[
    (corrs_df.corpus == 'Switchboard') &
    (corrs_df.type == 'iv')
].sort_values('corr', ascending=True).head(30)
# Out:
#             corpus            model n_samples          sampling
# 17823  Switchboard   DialoGPT Large       100  Temperature_1.25  \
# 17822  Switchboard   DialoGPT Large       100  Temperature_1.25
# 17646  Switchboard   DialoGPT Large        90  Temperature_1.25
# 17647  Switchboard   DialoGPT Large        90  Temperature_1.25
# 24703  Switchboard      GPT-2 Small        90      Typical_0.95
# 24702  Switchboard      GPT-2 Small        90      Typical_0.95
# 24879  Switchboard      GPT-2 Small       100      Typical_0.95
# 24878  Switchboard      GPT-2 Small       100      Typical_0.95
# 19742  Switchboard      GPT-2 Large       100    Ancestral_None
# 19743  Switchboard      GPT-2 Large       100    Ancestral_None
# 17470  Switchboard   DialoGPT Large        80  Temperature_1.25
# 17471  Switchboard   DialoGPT Large        80  Temperature_1.25
# 24862  Switchboard      GPT-2 Small       100  Temperature_1.25
# 24863  Switchboard      GPT-2 Small       100  Temperature_1.25
# 26734  Switchboard     GPT-Neo 1.3B       100      Typical_0.85
# 26735  Switchboard     GPT-Neo 1.3B       100      Typical_0.85
# 26558  Switchboard     GPT-Neo 1.3B        90      Typical_0.85
# 26559  Switchboard     GPT-Neo 1.3B        90      Typical_0.85
# 17815  Switchboard   DialoGPT Large       100  Temperature_1.25
# 26382  Switchboard     GPT-Neo 1.3B        80      Typical_0.85
# 26383  Switchboard     GPT-Neo 1.3B        80      Typical_0.85
# 17871  Switchboard   DialoGPT Large       100       Nucleus_0.9
# 17870  Switchboard   DialoGPT Large       100       Nucleus_0.9
# 21503  Switchboard  DialoGPT Medium       100    Ancestral_None
# 21502  Switchboard  DialoGPT Medium       100    Ancestral_None
# 17694  Switchboard   DialoGPT Large        90       Nucleus_0.9
# 17695  Switchboard   DialoGPT Large        90       Nucleus_0.9
# 17639  Switchboard   DialoGPT Large        90  Temperature_1.25
# 17814  Switchboard   DialoGPT Large       100  Temperature_1.25
# 21159  Switchboard  DialoGPT Medium        90  Temperature_1.25
#
#                        measure   agg      corr       p-value type
# 17823   surprise_min_euclidean  None -0.702414  3.832227e-16   iv
# 17822      surprise_min_cosine  None -0.702414  3.832227e-16   iv
# 17646      surprise_min_cosine  None -0.692922  1.375102e-15   iv
# 17647   surprise_min_euclidean  None -0.692922  1.375102e-15   iv
# 24703   surprise_min_euclidean  None -0.692855  1.387327e-15   iv
# 24702      surprise_min_cosine  None -0.692855  1.387327e-15   iv
# 24879   surprise_min_euclidean  None -0.688118  2.576984e-15   iv
# 24878      surprise_min_cosine  None -0.688118  2.576984e-15   iv
# 19742      surprise_min_cosine  None -0.681657  5.885868e-15   iv
# 19743   surprise_min_euclidean  None -0.681657  5.885868e-15   iv
# 17470      surprise_min_cosine  None -0.680088  7.170231e-15   iv
# 17471   surprise_min_euclidean  None -0.680088  7.170231e-15   iv
# 24862      surprise_min_cosine  None -0.679927  7.316152e-15   iv
# 24863   surprise_min_euclidean  None -0.679927  7.316152e-15   iv
# 26734      surprise_min_cosine  None -0.678615  8.620250e-15   iv
# 26735   surprise_min_euclidean  None -0.678615  8.620250e-15   iv
# 26558      surprise_min_cosine  None -0.675657  1.243817e-14   iv
# 26559   surprise_min_euclidean  None -0.675657  1.243817e-14   iv
# 17815  surprise_mean_euclidean  None -0.674861  1.371757e-14   iv
# 26382      surprise_min_cosine  None -0.674593  1.417731e-14   iv
# 26383   surprise_min_euclidean  None -0.674593  1.417731e-14   iv
# 17871   surprise_min_euclidean  None -0.674274  1.474236e-14   iv
# 17870      surprise_min_cosine  None -0.674274  1.474236e-14   iv
# 21503   surprise_min_euclidean  None -0.673793  1.563678e-14   iv
# 21502      surprise_min_cosine  None -0.673793  1.563678e-14   iv
# 17694      surprise_min_cosine  None -0.671882  1.974045e-14   iv
# 17695   surprise_min_euclidean  None -0.671882  1.974045e-14   iv
# 17639  surprise_mean_euclidean  None -0.671495  2.068919e-14   iv
# 17814     surprise_mean_cosine  None -0.671387  2.096242e-14   iv
# 21159  surprise_mean_euclidean  None -0.669235  2.718135e-14   iv

# %%
corrs_df[
    (corrs_df.corpus == 'Dailydialog') &
    (corrs_df.type == 'surprisal')
].sort_values('corr', ascending=True).head(30)
# Out:
#             corpus            model n_samples        sampling
# 5375   Dailydialog      GPT-2 Large        90     Nucleus_0.9  \
# 5374   Dailydialog      GPT-2 Large        90     Nucleus_0.9
# 5551   Dailydialog      GPT-2 Large       100     Nucleus_0.9
# 5550   Dailydialog      GPT-2 Large       100     Nucleus_0.9
# 5198   Dailydialog      GPT-2 Large        80     Nucleus_0.9
# 5199   Dailydialog      GPT-2 Large        80     Nucleus_0.9
# 11918  Dailydialog     GPT-Neo 1.3B        60     Nucleus_0.8
# 11919  Dailydialog     GPT-Neo 1.3B        60     Nucleus_0.8
# 5022   Dailydialog      GPT-2 Large        70     Nucleus_0.9
# 5023   Dailydialog      GPT-2 Large        70     Nucleus_0.9
# 11567  Dailydialog     GPT-Neo 1.3B        40     Nucleus_0.8
# 11566  Dailydialog     GPT-Neo 1.3B        40     Nucleus_0.8
# 11391  Dailydialog     GPT-Neo 1.3B        30     Nucleus_0.8
# 11390  Dailydialog     GPT-Neo 1.3B        30     Nucleus_0.8
# 12446  Dailydialog     GPT-Neo 1.3B        90     Nucleus_0.8
# 12447  Dailydialog     GPT-Neo 1.3B        90     Nucleus_0.8
# 5487   Dailydialog      GPT-2 Large        90  Ancestral_None
# 5486   Dailydialog      GPT-2 Large        90  Ancestral_None
# 5662   Dailydialog      GPT-2 Large       100  Ancestral_None
# 5663   Dailydialog      GPT-2 Large       100  Ancestral_None
# 7055   Dailydialog  DialoGPT Medium        80    Nucleus_0.95
# 7054   Dailydialog  DialoGPT Medium        80    Nucleus_0.95
# 5135   Dailydialog      GPT-2 Large        70  Ancestral_None
# 5134   Dailydialog      GPT-2 Large        70  Ancestral_None
# 6703   Dailydialog  DialoGPT Medium        60    Nucleus_0.95
# 6702   Dailydialog  DialoGPT Medium        60    Nucleus_0.95
# 1823   Dailydialog     GPT-2 Medium        90    Typical_0.95
# 1822   Dailydialog     GPT-2 Medium        90    Typical_0.95
# 5310   Dailydialog      GPT-2 Large        80  Ancestral_None
# 5311   Dailydialog      GPT-2 Large        80  Ancestral_None
#
#                       measure   agg      corr       p-value type
# 5375   surprise_min_euclidean  None -0.584379  1.736895e-10   iv
# 5374      surprise_min_cosine  None -0.584379  1.736895e-10   iv
# 5551   surprise_min_euclidean  None -0.578579  2.889064e-10   iv
# 5550      surprise_min_cosine  None -0.578579  2.889064e-10   iv
# 5198      surprise_min_cosine  None -0.577742  3.106707e-10   iv
# 5199   surprise_min_euclidean  None -0.577742  3.106707e-10   iv
# 11918     surprise_min_cosine  None -0.575127  3.892641e-10   iv
# 11919  surprise_min_euclidean  None -0.575127  3.892641e-10   iv
# 5022      surprise_min_cosine  None -0.574599  4.072965e-10   iv
# 5023   surprise_min_euclidean  None -0.574599  4.072965e-10   iv
# 11567  surprise_min_euclidean  None -0.569654  6.200972e-10   iv
# 11566     surprise_min_cosine  None -0.569654  6.200972e-10   iv
# 11391  surprise_min_euclidean  None -0.566371  8.165439e-10   iv
# 11390     surprise_min_cosine  None -0.566371  8.165439e-10   iv
# 12446     surprise_min_cosine  None -0.559345  1.457005e-09   iv
# 12447  surprise_min_euclidean  None -0.559345  1.457005e-09   iv
# 5487   surprise_min_euclidean  None -0.558017  1.623175e-09   iv
# 5486      surprise_min_cosine  None -0.558017  1.623175e-09   iv
# 5662      surprise_min_cosine  None -0.557998  1.625573e-09   iv
# 5663   surprise_min_euclidean  None -0.557998  1.625573e-09   iv
# 7055   surprise_min_euclidean  None -0.557992  1.626373e-09   iv
# 7054      surprise_min_cosine  None -0.557992  1.626373e-09   iv
# 5135   surprise_min_euclidean  None -0.557646  1.672605e-09   iv
# 5134      surprise_min_cosine  None -0.557646  1.672605e-09   iv
# 6703   surprise_min_euclidean  None -0.557574  1.682497e-09   iv
# 6702      surprise_min_cosine  None -0.557574  1.682497e-09   iv
# 1823   surprise_min_euclidean  None -0.557191  1.735360e-09   iv
# 1822      surprise_min_cosine  None -0.557191  1.735360e-09   iv
# 5310      surprise_min_cosine  None -0.557167  1.738769e-09   iv
# 5311   surprise_min_euclidean  None -0.557167  1.738769e-09   iv

# %%
corrs_df[
    (corrs_df.corpus == 'Dailydialog') &
    (corrs_df.type == 'iv')
].sort_values('corr', ascending=True).head(30)

# %% [markdown]
# ## Find best estimator per corpus and linguistic level

# %%
# Out:
#             corpus           model n_samples          sampling
# 17822  Switchboard  DialoGPT Large       100  Temperature_1.25  \
# 17823  Switchboard  DialoGPT Large       100  Temperature_1.25
# 17647  Switchboard  DialoGPT Large        90  Temperature_1.25
# 17646  Switchboard  DialoGPT Large        90  Temperature_1.25
# 24703  Switchboard     GPT-2 Small        90      Typical_0.95
# 24702  Switchboard     GPT-2 Small        90      Typical_0.95
# 24878  Switchboard     GPT-2 Small       100      Typical_0.95
# 24879  Switchboard     GPT-2 Small       100      Typical_0.95
# 19742  Switchboard     GPT-2 Large       100    Ancestral_None
# 19743  Switchboard     GPT-2 Large       100    Ancestral_None
# 17470  Switchboard  DialoGPT Large        80  Temperature_1.25
# 17471  Switchboard  DialoGPT Large        80  Temperature_1.25
# 24862  Switchboard     GPT-2 Small       100  Temperature_1.25
# 24863  Switchboard     GPT-2 Small       100  Temperature_1.25
# 26735  Switchboard    GPT-Neo 1.3B       100      Typical_0.85
# 26734  Switchboard    GPT-Neo 1.3B       100      Typical_0.85
# 26558  Switchboard    GPT-Neo 1.3B        90      Typical_0.85
# 26559  Switchboard    GPT-Neo 1.3B        90      Typical_0.85
# 17815  Switchboard  DialoGPT Large       100  Temperature_1.25
# 26382  Switchboard    GPT-Neo 1.3B        80      Typical_0.85
#
#                        measure   agg      corr       p-value type
# 17822      surprise_min_cosine  None -0.702414  3.832227e-16   iv
# 17823   surprise_min_euclidean  None -0.702414  3.832227e-16   iv
# 17647   surprise_min_euclidean  None -0.692922  1.375102e-15   iv
# 17646      surprise_min_cosine  None -0.692922  1.375102e-15   iv
# 24703   surprise_min_euclidean  None -0.692855  1.387327e-15   iv
# 24702      surprise_min_cosine  None -0.692855  1.387327e-15   iv
# 24878      surprise_min_cosine  None -0.688118  2.576984e-15   iv
# 24879   surprise_min_euclidean  None -0.688118  2.576984e-15   iv
# 19742      surprise_min_cosine  None -0.681657  5.885868e-15   iv
# 19743   surprise_min_euclidean  None -0.681657  5.885868e-15   iv
# 17470      surprise_min_cosine  None -0.680088  7.170231e-15   iv
# 17471   surprise_min_euclidean  None -0.680088  7.170231e-15   iv
# 24862      surprise_min_cosine  None -0.679927  7.316152e-15   iv
# 24863   surprise_min_euclidean  None -0.679927  7.316152e-15   iv
# 26735   surprise_min_euclidean  None -0.678615  8.620250e-15   iv
# 26734      surprise_min_cosine  None -0.678615  8.620250e-15   iv
# 26558      surprise_min_cosine  None -0.675657  1.243817e-14   iv
# 26559   surprise_min_euclidean  None -0.675657  1.243817e-14   iv
# 17815  surprise_mean_euclidean  None -0.674861  1.371757e-14   iv
# 26382      surprise_min_cosine  None -0.674593  1.417731e-14   iv

# %%
corrs_df[
    (corrs_df.corpus == 'Switchboard') &
    (corrs_df.type == "iv") &
    (corrs_df.measure.str.contains('cosine') | corrs_df.measure.str.contains('euclidean'))
].sort_values('corr', ascending=True).head(20)
# Out:
#             corpus            model n_samples          sampling
# 20809  Switchboard  DialoGPT Medium        70  Temperature_1.25  \
# 20985  Switchboard  DialoGPT Medium        80  Temperature_1.25
# 21161  Switchboard  DialoGPT Medium        90  Temperature_1.25
# 21337  Switchboard  DialoGPT Medium       100  Temperature_1.25
# 20633  Switchboard  DialoGPT Medium        60  Temperature_1.25
# 20457  Switchboard  DialoGPT Medium        50  Temperature_1.25
# 21482  Switchboard  DialoGPT Medium       100      Nucleus_0.95
# 21130  Switchboard  DialoGPT Medium        80      Nucleus_0.95
# 21642  Switchboard     GPT-Neo 125M        10       Typical_0.3
# 21496  Switchboard  DialoGPT Medium       100    Ancestral_None
# 21306  Switchboard  DialoGPT Medium        90      Nucleus_0.95
# 21634  Switchboard     GPT-Neo 125M        10       Typical_0.3
# 17480  Switchboard   DialoGPT Large        80      Typical_0.95
# 17832  Switchboard   DialoGPT Large       100      Typical_0.95
# 21320  Switchboard  DialoGPT Medium        90    Ancestral_None
# 17656  Switchboard   DialoGPT Large        90      Typical_0.95
# 26408  Switchboard     GPT-Neo 1.3B        80      Nucleus_0.95
# 22298  Switchboard     GPT-Neo 125M        50       Nucleus_0.8
# 16216  Switchboard     GPT-2 Medium       100    Ancestral_None
# 21481  Switchboard  DialoGPT Medium       100      Nucleus_0.95
#
#                    measure   agg      corr   p-value type
# 20809   surprise_min_2gram  None -0.436460  0.000017   iv
# 20985   surprise_min_2gram  None -0.407725  0.000066   iv
# 21161   surprise_min_2gram  None -0.402159  0.000085   iv
# 21337   surprise_min_2gram  None -0.401664  0.000087   iv
# 20633   surprise_min_2gram  None -0.392563  0.000130   iv
# 20457   surprise_min_2gram  None -0.369605  0.000337   iv
# 21482   surprise_min_3gram  None -0.354729  0.000748   iv
# 21130   surprise_min_3gram  None -0.345498  0.001047   iv
# 21642   surprise_min_3gram  None -0.340502  0.001251   iv
# 21496   surprise_min_1gram  None -0.340300  0.000532   iv
# 21306   surprise_min_3gram  None -0.339973  0.001274   iv
# 21634  surprise_mean_3gram  None -0.329562  0.001827   iv
# 17480   surprise_min_1gram  None -0.325551  0.000949   iv
# 17832   surprise_min_1gram  None -0.323992  0.001008   iv
# 21320   surprise_min_1gram  None -0.322381  0.001071   iv
# 17656   surprise_min_1gram  None -0.322302  0.001075   iv
# 26408   surprise_min_1gram  None -0.320370  0.001156   iv
# 22298   surprise_min_3gram  None -0.319741  0.002537   iv
# 16216   surprise_min_1gram  None -0.319002  0.001217   iv
# 21481   surprise_min_2gram  None -0.315737  0.002434   iv

# %%
corrs_df[
    (corrs_df.corpus == 'Switchboard') &
    (corrs_df.type == "iv") &
    (~corrs_df.measure.str.contains('cosine')) &
    (~corrs_df.measure.str.contains('euclidean')) &
    (~corrs_df.measure.str.contains('pos'))
].sort_values('corr', ascending=True).head(20)
# Out:
#             corpus           model n_samples          sampling
# 28540  Switchboard  DialoGPT Small       100    Ancestral_None  \
# 28364  Switchboard  DialoGPT Small        90    Ancestral_None
# 26461  Switchboard    GPT-Neo 1.3B        90      Typical_0.95
# 28188  Switchboard  DialoGPT Small        80    Ancestral_None
# 23261  Switchboard    GPT-Neo 125M       100    Ancestral_None
# 23260  Switchboard    GPT-Neo 125M       100    Ancestral_None
# 26637  Switchboard    GPT-Neo 1.3B       100      Typical_0.95
# 22908  Switchboard    GPT-Neo 125M        80    Ancestral_None
# 23084  Switchboard    GPT-Neo 125M        90    Ancestral_None
# 24860  Switchboard     GPT-2 Small       100  Temperature_1.25
#
#                       measure   agg      corr   p-value type
# 28540  surprise_min_2gram_pos  None -0.440380  0.000014   iv
# 28364  surprise_min_2gram_pos  None -0.406467  0.000070   iv
# 26461  surprise_min_3gram_pos  None -0.392518  0.000170   iv
# 28188  surprise_min_2gram_pos  None -0.391849  0.000134   iv
# 23261  surprise_min_3gram_pos  None -0.391002  0.000181   iv
# 23260  surprise_min_2gram_pos  None -0.374333  0.000278   iv
# 26637  surprise_min_3gram_pos  None -0.372024  0.000388   iv
# 22908  surprise_min_2gram_pos  None -0.371991  0.000306   iv
# 23084  surprise_min_2gram_pos  None -0.361208  0.000469   iv
# 24860  surprise_min_2gram_pos  None -0.360643  0.000480   iv

# %%
corrs_df[
    (corrs_df.corpus == 'Switchboard') &
    (corrs_df.type == "iv") &
    (corrs_df.measure.str.contains('pos'))
].sort_values('corr', ascending=True).head(10)

# %%
# Out:
#             corpus         model n_samples     sampling
# 5374   Dailydialog   GPT-2 Large        90  Nucleus_0.9  \
# 5375   Dailydialog   GPT-2 Large        90  Nucleus_0.9
# 5551   Dailydialog   GPT-2 Large       100  Nucleus_0.9
# 5550   Dailydialog   GPT-2 Large       100  Nucleus_0.9
# 5199   Dailydialog   GPT-2 Large        80  Nucleus_0.9
# 5198   Dailydialog   GPT-2 Large        80  Nucleus_0.9
# 11918  Dailydialog  GPT-Neo 1.3B        60  Nucleus_0.8
# 11919  Dailydialog  GPT-Neo 1.3B        60  Nucleus_0.8
# 5023   Dailydialog   GPT-2 Large        70  Nucleus_0.9
# 5022   Dailydialog   GPT-2 Large        70  Nucleus_0.9
#
#                       measure   agg      corr       p-value type
# 5374      surprise_min_cosine  None -0.584379  1.736895e-10   iv
# 5375   surprise_min_euclidean  None -0.584379  1.736895e-10   iv
# 5551   surprise_min_euclidean  None -0.578579  2.889064e-10   iv
# 5550      surprise_min_cosine  None -0.578579  2.889064e-10   iv
# 5199   surprise_min_euclidean  None -0.577742  3.106707e-10   iv
# 5198      surprise_min_cosine  None -0.577742  3.106707e-10   iv
# 11918     surprise_min_cosine  None -0.575127  3.892641e-10   iv
# 11919  surprise_min_euclidean  None -0.575127  3.892641e-10   iv
# 5023   surprise_min_euclidean  None -0.574599  4.072965e-10   iv
# 5022      surprise_min_cosine  None -0.574599  4.072965e-10   iv

# %%
corrs_df[
    (corrs_df.corpus == 'Dailydialog') &
    (corrs_df.type == "iv") &
    (corrs_df.measure.str.contains('cosine') | corrs_df.measure.str.contains('euclidean'))
].sort_values('corr', ascending=True).head(10)
# Out:
#             corpus            model n_samples          sampling
# 14104  Dailydialog   DialoGPT Small        80    Ancestral_None  \
# 6232   Dailydialog  DialoGPT Medium        40  Temperature_0.75
# 14456  Dailydialog   DialoGPT Small       100    Ancestral_None
# 5544   Dailydialog      GPT-2 Large       100       Nucleus_0.9
# 3832   Dailydialog   DialoGPT Large       100      Nucleus_0.85
# 14280  Dailydialog   DialoGPT Small        90    Ancestral_None
# 6408   Dailydialog  DialoGPT Medium        50  Temperature_0.75
# 5016   Dailydialog      GPT-2 Large        70       Nucleus_0.9
# 12456  Dailydialog     GPT-Neo 1.3B        90      Nucleus_0.85
# 12632  Dailydialog     GPT-Neo 1.3B       100      Nucleus_0.85
#
#                   measure   agg      corr   p-value type
# 14104  surprise_min_1gram  None -0.383088  0.000084   iv
# 6232   surprise_min_1gram  None -0.381579  0.000090   iv
# 14456  surprise_min_1gram  None -0.377049  0.000110   iv
# 5544   surprise_min_1gram  None -0.376168  0.000115   iv
# 3832   surprise_min_1gram  None -0.372974  0.000133   iv
# 14280  surprise_min_1gram  None -0.371960  0.000139   iv
# 6408   surprise_min_1gram  None -0.371375  0.000142   iv
# 5016   surprise_min_1gram  None -0.370335  0.000149   iv
# 12456  surprise_min_1gram  None -0.367728  0.000167   iv
# 12632  surprise_min_1gram  None -0.367337  0.000170   iv

# %%
corrs_df[
    (corrs_df.corpus == 'Dailydialog') &
    (corrs_df.type == "iv") &
    (~corrs_df.measure.str.contains('cosine')) &
    (~corrs_df.measure.str.contains('euclidean')) &
    (~corrs_df.measure.str.contains('pos'))
].sort_values('corr', ascending=True).head(10)
# Out:
#             corpus           model n_samples          sampling
# 3565   Dailydialog  DialoGPT Large        90  Temperature_1.25  \
# 1757   Dailydialog    GPT-2 Medium        80       Typical_0.3
# 3741   Dailydialog  DialoGPT Large       100  Temperature_1.25
# 1581   Dailydialog    GPT-2 Medium        70       Typical_0.3
# 14109  Dailydialog  DialoGPT Small        80    Ancestral_None
# 3213   Dailydialog  DialoGPT Large        70  Temperature_1.25
# 14461  Dailydialog  DialoGPT Small       100    Ancestral_None
# 3037   Dailydialog  DialoGPT Large        60  Temperature_1.25
# 14285  Dailydialog  DialoGPT Small        90    Ancestral_None
# 1933   Dailydialog    GPT-2 Medium        90       Typical_0.3
#
#                       measure   agg      corr   p-value type
# 3565   surprise_min_3gram_pos  None -0.358922  0.000284   iv
# 1757   surprise_min_3gram_pos  None -0.346284  0.000417   iv
# 3741   surprise_min_3gram_pos  None -0.346038  0.000483   iv
# 1581   surprise_min_3gram_pos  None -0.339266  0.000554   iv
# 14109  surprise_min_3gram_pos  None -0.333806  0.000782   iv
# 3213   surprise_min_3gram_pos  None -0.329093  0.000937   iv
# 14461  surprise_min_3gram_pos  None -0.325886  0.001058   iv
# 3037   surprise_min_3gram_pos  None -0.325052  0.001092   iv
# 14285  surprise_min_3gram_pos  None -0.323572  0.001154   iv
# 1933   surprise_min_3gram_pos  None -0.313400  0.001498   iv

# %%
corrs_df[
    (corrs_df.corpus == 'Dailydialog') &
    (corrs_df.type == "iv") &
    (corrs_df.measure.str.contains('pos'))
].sort_values('corr', ascending=True).head(10)
